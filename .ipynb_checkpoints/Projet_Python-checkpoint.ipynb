# %% [markdown]
# # Projet Python : Santé

# %% [markdown]
# ## Récupération des données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#test avec Selenium

# %%
#pip install selenium
# Out:
# ...
#      |████████████████████████████████| 904 kB 4.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import time  #mettre des script en pause pour les chargement de la page
from selenium import webdriver #module qui gère le navigateur
from selenium.webdriver.common.keys import Keys #la classe keus permet d'utiliser les touches du clavier
from selenium.webdriver import Chrome

# %%
#path_to_web_driver = "chromedriver"

# %%
#chrome_options=webdriver.ChromeOptions()

# %%
#On crée une instance du web-driver Chrome et on va sur la page sélectionnée
driver = webdriver.Chrome("/Users/antoineloubeyre/Downloads/chromedriver-5")

driver.get("https://geodes.santepubliquefrance.fr/#view=map2&c=indicator")

time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-395807eebf5a> in <module>
#       1 #On crée une instance du web-driver Chrome et on va sur la page sélectionnée
# ----> 2 driver = webdriver.Chrome("/Users/antoineloubeyre/Downloads/chromedriver-5")
#       3
#       4 driver.get("https://geodes.santepubliquefrance.fr/#view=map2&c=indicator")
#       5
#
# NameError: name 'webdriver' is not defined

# %%
#Balises des maladies asthme/ Allergie / ORL / Pneumopathie / Bronchiolite
#bronchite </ grippe

#Sélection maladie a asthme

#driver.find_element_by_xpath("//div[@data-pk='patho_a']").click()
#time.sleep(1)

#Click sur asthme

#driver.find_element_by_xpath("//li[@data-pk='asthme']").click()
#time.sleep(1)

#Click sur taux d'hospitalisation pour asthme

#driver.find_element_by_xpath("//div[@data-pk='sursaud_sau.prop_asthme_hospit_sau']").click()
#time.sleep(1)

#Click sur tous les âges (changer le numéro au cas où)

#driver.find_element_by_xpath("//li[@data-jsv='#204^#505_#506_']").click()
#time.sleep(1)






#Sélection maladie allergie

#driver.find_element_by_xpath("//div[@data-pk='patho_a']").click()
#time.sleep(1)

#Click sur alllergie

#driver.find_element_by_xpath("//li[@data-pk='allergie']").click()
#time.sleep(1)

#Click sur taux d'hospitalisation pour allergie

#driver.find_element_by_xpath("//div[@data-pk='sursaud_sau.prop_allergie_hospit_sau']").click()
#time.sleep(1)

#Click sur tous les âges (changer le numéro au cas où)

#driver.find_element_by_xpath("//li[@data-jsv='#204^#505_#506_']").click()
#time.sleep(1)





#Sélection ORL

#driver.find_element_by_xpath("//div[@data-pk='patho_o']").click()
#time.sleep(1)

#Click sur alllergie

#driver.find_element_by_xpath("//li[@data-pk='orl']").click()
#time.sleep(1)


#Click sur taux d'hospitalisation pour orl

#driver.find_element_by_xpath("//div[@data-pk='sursaud_sau.prop_orl_hospit_sau']").click()
#time.sleep(1)

#Click sur tous les âges (changer le numéro au cas où)

#driver.find_element_by_xpath("//li[@data-jsv='#275^#638_#639_']").click()
#time.sleep(1)




#Sélection Pneumopathie

#driver.find_element_by_xpath("//div[@data-pk='patho_p']").click()
#time.sleep(1)

#Click sur pneum

#driver.find_element_by_xpath("//li[@data-pk='pneumo']").click()
#time.sleep(1)


#Click sur taux d'hospitalisation 

#driver.find_element_by_xpath("//div[@data-pk='sursaud_sau.prop_pneumo_hospit_sau']").click()
#time.sleep(1)

#Click sur tous les âges (changer le numéro au cas où)

#driver.find_element_by_xpath("//li[@data-jsv='#264^#604_#605_']").click()
#time.sleep(1)



#Sélection Bronchiolite

#driver.find_element_by_xpath("//div[@data-pk='patho_b']").click()
#time.sleep(1)

#Click sur pneum

#driver.find_element_by_xpath("//li[@data-pk='bronchiolite']").click()
#time.sleep(1)


#Click sur taux d'hospitalisation 

#driver.find_element_by_xpath("//div[@data-pk='sursaud_bronchio.prop_bronchio_hospit_sau']").click()
#time.sleep(1)




#Sélection bronchite

#driver.find_element_by_xpath("//div[@data-pk='patho_b']").click()
#time.sleep(1)

#Click sur pneum

#driver.find_element_by_xpath("//li[@data-pk='bronchite']").click()
#time.sleep(1)


#Click sur taux d'hospitalisation 

#driver.find_element_by_xpath("//div[@data-pk='sursaud_sau.prop_bronchite_hospit_sau']").click()
#time.sleep(1)

#Click sur tous les âges (changer le numéro au cas où)

#driver.find_element_by_xpath("//li[@data-jsv='#364^#734_#735_']").click()
#time.sleep(1)




#Sélection grippe

#driver.find_element_by_xpath("//div[@data-pk='patho_g']").click()
#time.sleep(1)

#Click sur pneum

#driver.find_element_by_xpath("//li[@data-pk='grippe']").click()
#time.sleep(1)


#Click sur taux d'hospitalisation 

#driver.find_element_by_xpath("//div[@data-pk='sursaud_sau.prop_grippe_hospi_sau']").click()
#time.sleep(1)

#Click sur tous les âges (changer le numéro au cas où)

#driver.find_element_by_xpath("//li[@data-jsv='#399^#775_#776_']").click()
#time.sleep(1)

# %%
#test boucle kenza récupération donnée 


driver.find_element_by_xpath("//a[@id='tm_table']").click()
time.sleep(1)


#test de la boucle avec 3 maladies

onglet=["A","O","P"]

data_pk_gros=["//div[@data-pk='patho_a']", "//div[@data-pk='patho_o']", "//div[@data-pk='patho_p']"]

data_pk_moyen= [["//li[@data-pk='asthme']"], ["//li[@data-pk='orl']"], ["//li[@data-pk='pneumo']" ]]

data_pk_petit = [[["//div[@data-pk='sursaud_sau.prop_asthme_hospit_sau']"]], [["//div[@data-pk='sursaud_sau.prop_orl_hospit_sau']"]], [["//div[@data-pk='sursaud_sau.prop_pneumo_hospit_sau']"]]]

data_pk_mini= [[["//li[@data-jsv='#204^#505_#506_']"]], [["//li[@data-jsv='#275^#638_#639_']"]], [["//li[@data-jsv='#264^#604_#605_']"]]]




driver.find_element_by_xpath("//a[@id='tm_table']").click()
time.sleep(1)

for i in range(len(data_pk_gros)):
    driver.find_element_by_xpath(data_pk_gros[i]).click()
    time.sleep(1)
    for j in range(len(data_pk_moyen[i])):
        driver.find_element_by_xpath(data_pk_moyen[i][j]).click()
        time.sleep(1)
        for k in range(len(data_pk_petit[i][j])):
            driver.find_element_by_xpath(data_pk_petit[i][j][k]).click()
            time.sleep(1)
            for l in range(len(data_pk_mini[i][j][k])):
                driver.find_element_by_xpath(data_pk_mini[i][j][k][l]).click()
                time.sleep(1)
                
        zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
        zone_retour.find_element_by_partial_link_text(onglet[i]).click()
        
        
        
# On récupère le tableau

L = []

Table = driver.find_element_by_xpath("//tbody")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data = L[16 : len(L) - 2]
