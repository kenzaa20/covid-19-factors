# %% [markdown]
# # Projet Python : Santé

# %% [markdown]
# ## Récupération des données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#test avec Selenium

# %%
#pip install selenium
# Out:
# ...
#      |████████████████████████████████| 904 kB 4.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import time  #mettre des script en pause pour les chargement de la page
from selenium import webdriver #module qui gère le navigateur
from selenium.webdriver.common.keys import Keys #la classe keys permet d'utiliser les touches du clavier
from selenium.webdriver import Chrome

# %%
#path_to_web_driver = "chromedriver"

# %%
#chrome_options=webdriver.ChromeOptions()

# %%
#On crée une instance du web-driver Chrome et on va sur la page sélectionnée
driver = webdriver.Chrome("/Users/antoineloubeyre/Downloads/chromedriver-5")

driver.get("https://geodes.santepubliquefrance.fr/#view=map2&c=indicator")

time.sleep(2)

# %%
# On recupere la bar de recherche
search_bar = driver.find_element_by_name("search")
search_bar.send_keys("covid")
search_bar.send_keys(Keys.ENTER)

time.sleep(1)

# Clique sur le sous lien Covid
driver.find_element_by_class_name("ui-collapsible-content ").click()

time.sleep(1)


#Clique sur les données hospitalières
driver.find_element_by_xpath("//span[@class='ui-li-label level2']").click()


time.sleep(1)


#Sélection nombre cumulé de décès par âge
driver.find_element_by_xpath("//h3[@class='ui-collapsible-heading filter1']").click()

time.sleep(1)


#Sélection tous les âges
driver.find_element_by_xpath("//li[@data-jsv='#198^#506_#507_']").click()

# %%
# Nouvelle recherche pour Asthme

search_bar.clear()

time.sleep(1)
search_bar.send_keys("Asthme")
search_bar.send_keys(Keys.ENTER)

time.sleep(1)

# %%
#Sélection tous les âges 

#pb prends seulement 65 ans et plus

driver.find_element_by_xpath("//li[@data-jsv='#1314^#2149_#2150_']").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-108-97a61541719c> in <module>
#       3 #pb prends seulement 65 ans et plus
#       4
# ----> 5 driver.find_element_by_xpath("//li[@data-jsv='#1314^#2149_#2150_']").click()
#       6
#       7
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# ...

# %%
# Nouvelle recherche pour Allergies

search_bar.clear()

time.sleep(1)
search_bar.send_keys("Allergie")
search_bar.send_keys(Keys.ENTER)


timple.sleep(1)

#sélection tous les âges
driver.find_element_by_xpath("//li[@data-jsv='#2878^#4002_#4003_']").click()

# %%
#Sélection options régions
driver.find_element_by_xpath("//select[@id='tm_view_cb']").click()

#sleep(2)

#Sélection des départements 2019
driver.find_element_by_xpath("//option[@data-jsv='/387_#388_']").click()

# %%
# Affichage des données sur la carte

driver.find_element_by_xpath("//li[@data-jsv='/1000_']").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-69a98db01262> in <module>
#       1 # Affichage des données sur la carte
#       2
# ----> 3 driver.find_element_by_xpath("//li[@data-jsv='/1000_']").click()
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
driver.find_element_by_xpath("//li[@class='js-tablist__item tiny-hiddenXX tabs__item']").click()

# %%
#Récupération du tableau

results=driver.find_element_by_xpath("//table[@id='tm_datatable']").text

# %%
results=driver.find_element_by_xpath("//div[@class='dataTables_scroll']").text

# %%
print(results)
type(results)
# Out:
# Code Libellé Nombre quotidien de nouveaux décès 2020-11-04
# 01 Ain 6
# 02 Aisne 5
# 03 Allier 7
# 04 Alpes-de-Haute-Provence 0
# 05 Hautes-Alpes 0
# 06 Alpes-Maritimes 2
# 07 Ardèche 5
# 08 Ardennes 0
# 09 Ariège 0
# 10 Aube 0
# 11 Aude 2
# 12 Aveyron 0
# 13 Bouches-du-Rhône 26
# 14 Calvados 3
# 15 Cantal 0
# 16 Charente 0
# 17 Charente-Maritime 2
# 18 Cher 2
# 19 Corrèze 0
# 21 Côte-d'Or 5
# 22 Côtes-d'Armor 1
# 23 Creuse 0
# 24 Dordogne 1
# 25 Doubs 2
# 26 Drôme 8
# 27 Eure 4
# 28 Eure-et-Loir 3
# 29 Finistère 0
# 2A Corse-du-Sud 1
# 2B Haute-Corse 1
# 30 Gard 6
# 31 Haute-Garonne 7
# 32 Gers 1
# 33 Gironde 4
# 34 Hérault 3
# 35 Ille-et-Vilaine 2
# 36 Indre 0
# 37 Indre-et-Loire 1
# 38 Isère 19
# 39 Jura 1
# 40 Landes 0
# 41 Loir-et-Cher 1
# 42 Loire 11
# 43 Haute-Loire 2
# 44 Loire-Atlantique 4
# 45 Loiret 1
# 46 Lot 0
# 47 Lot-et-Garonne 0
# 48 Lozère 3
# 49 Maine-et-Loire 6
# 50 Manche 2
# 51 Marne 1
# 52 Haute-Marne 2
# 53 Mayenne 5
# 54 Meurthe-et-Moselle 3
# 55 Meuse 1
# ...

# %%
import io
import pandas as pd

data = io.StringIO(results)
df = pd.read_csv(data, sep=";")

# %%
df.head(10)
#df.columns
# Out:
#   Code Libellé Nombre quotidien de nouveaux décès 2020-11-04
# 0                                           01 Ain 6
# 1                                         02 Aisne 5
# 2                                        03 Allier 7
# 3                       04 Alpes-de-Haute-Provence 0
# 4                                  05 Hautes-Alpes 0
# 5                               06 Alpes-Maritimes 2
# 6                                       07 Ardèche 5
# 7                                      08 Ardennes 0
# 8                                        09 Ariège 0
# 9                                          10 Aube 0

# %%
df2=df['Code Libellé Nombre quotidien de nouveaux décès 2020-11-04'].str.split(" ",1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Code Libellé Nombre quotidien de nouveaux décès 2020-11-04'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
type(df2)
df2.head()
# Out:
# 0                        [01, Ain 6]
# 1                      [02, Aisne 5]
# 2                     [03, Allier 7]
# 3    [04, Alpes-de-Haute-Provence 0]
# 4               [05, Hautes-Alpes 0]
# Name: Code Libellé Nombre quotidien de nouveaux décès 2020-11-04, dtype: object

# %%
out = pd.DataFrame(df["Code Libellé Nombre quotidien de nouveaux décès 2020-11-04"].str.split(' ',2).tolist(),columns=['Code','departement','décès'])
out.drop(index=0,inplace=True)

# %%
out.head(30)
# Out:
#    Code          departement                                          décès
# 1    02           Martinique                                             22
# 2    03               Guyane                                              0
# 3    04              Réunion                                              3
# 4    06              Mayotte                                             12
# 5    11        Île-de-France                                          3 941
# 6    24           Centre-Val                                   de Loire 348
# 7    27            Bourgogne                           et Franche-Comté 461
# 8    28            Normandie                                            203
# 9    32      Hauts-de-France                                            459
# 10   44                Grand                                      Est 2 479
# 11   52                 Pays                                de la Loire 202
# ...

# %%
split_data = df["Code Libellé Nombre cumulé de décès par âge 2020-08-16 - tous âges"].str.split(", ")
data = split_data.to_list()
print(data)
#names = ["Code", "Departement","dead","autres"]
#new_df = pd.DataFrame(data, columns=names)

#print(new_df)
# Out:
# [['01 Guadeloupe 2'], ['02 Martinique 22'], ['03 Guyane 0'], ['04 Réunion 3'], ['06 Mayotte 12'], ['11 Île-de-France 3\u202f941'], ['24 Centre-Val de Loire 348'], ['27 Bourgogne et Franche-Comté 461'], ['28 Normandie 203'], ['32 Hauts-de-France 459'], ['44 Grand Est 2\u202f479'], ['52 Pays de la Loire 202'], ['53 Bretagne 122'], ['75 Nouvelle Aquitaine 473'], ['76 Occitanie 514'], ['84 Auvergne et Rhône-Alpes 1\u202f408'], ["93 Provence-Alpes-Côte d'Azur 691"], ['94 Corse 0'], ['975 Miquelon-Langlade et Saint Pierre N/A - résultat non disponible'], ['977 Saint-Barthélemy N/A - résultat non disponible'], ['978 Saint-Martin N/A - résultat non disponible']]

# %% [markdown]
# # Les 3 cellules suivantes

# %%
from selenium.webdriver.common.action_chains import ActionChains

driver = webdriver.Firefox()

driver.get("https://geodes.santepubliquefrance.fr/#c=indicator&view=map2")
time.sleep(2)

# %%
onglet = ['A','B', 'G','O', 'P']
data_pk_gros = ["//div[@data-pk='patho_a']","//div[@data-pk='patho_b']","//div[@data-pk='patho_g']", "//div[@data-pk='patho_o']", "//div[@data-pk='patho_p']"]

data_pk_moyen = [["//li[@data-pk='asthme']","//li[@data-pk='allergie']" ],["//li[@data-pk='bronchite']" ],["//li[@data-pk='grippe']"], ["//li[@data-pk='orl']"], ["//li[@data-pk='pneumo']"]]

data_pk_petit = [[["//div[@data-pk='sursaud_sau.prop_asthme_hospit_sau']"],["//div[@data-pk='sursaud_sau.prop_allergie_hospit_sau']"]],[["//div[@data-pk='sursaud_sau.prop_bronchite_hospit_sau']"]],
                 [["//div[@data-pk='sursaud_sau.prop_grippe_hospi_sau']"]],[["//div[@data-pk='sursaud_sau.prop_orl_hospit_sau']"]],
                 [["//div[@data-pk='sursaud_sau.prop_pneumo_hospit_sau']"]]]

# %%
driver.find_element_by_xpath("//a[@id='tm_table']").click()
time.sleep(2)


for i in range(len(data_pk_gros)):
    driver.find_element_by_xpath(data_pk_gros[i]).click()
    time.sleep(1)
    for j in range(len(data_pk_moyen[i])):
        driver.find_element_by_xpath(data_pk_moyen[i][j]).click()
        time.sleep(1)
        for k in range(len(data_pk_petit[i][j])):
            driver.find_element_by_xpath(data_pk_petit[i][j][k]).click()
            time.sleep(1)
            driver.find_element_by_partial_link_text("tous âges").click()
        zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
        ActionChains(driver).move_to_element(zone_retour.find_element_by_link_text(onglet[i])).click().perform()
        #zone_retour.find_element_by_link_text(onglet[i]).click() J'ai dû écrire la ligne du dessus à la place c'est un pb propre à mon ordi

# %%
L = []

Table = driver.find_element_by_xpath("//tbody")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data = L[16 : len(L) - 2]

# %%
df = pd.DataFrame(data, columns = ['Code', 'Libellé', 'Taux hospitalisation asthme (2020 S45)', 'Taux hospitalisation allergie (2020 S45)', 'Taux hospitalisation bronchite (2020 S45)', 'Taux hospitalisation grippe (2020 S45)', 'Taux hospitalisation ORL (2020 S45)', 'Taux hospitalisation pneumopathie (2020 S45)'])
df.set_index('Code',inplace=True)
df
# Out:
#                                 Libellé  \
# Code
# 01                                  Ain
# 02                                Aisne
# 03                               Allier
# 04              Alpes-de-Haute-Provence
# 05                         Hautes-Alpes
# 06                      Alpes-Maritimes
# 07                              Ardèche
# 08                             Ardennes
# 09                               Ariège
# 10                                 Aube
# 11                                 Aude
# 12                              Aveyron
# 13                     Bouches-du-Rhône
# 14                             Calvados
# 15                               Cantal
# 16                             Charente
# 17                    Charente-Maritime
# 18                                 Cher
# 19                              Corrèze
# 21                            Côte-d'Or
# 22                        Côtes-d'Armor
# 23                               Creuse
# ...

# %% [markdown]
# Nombre cumulé de décès
# Nombre de personnes actuellement hospitalisées
# Nombre de personnes actuellement en réanimation
# Taux de posivité - semaine glissante

# %%
"//li[@data-pk='covid_sidep']"  "//div[@data-pk='sp_ti_tp_7j.tx_pos_gliss']"   'Taux de posivité - Semaine glissante'

# %%
data_pk_c_moyen_family = [["//li[@data-pk='covid_cedc']", "//li[@data-pk='covid_sivic']"], ["//li[@data-pk='covid_sivic']"], ["//li[@data-pk='covid_oscour']"], ["//li[@data-pk='covid_cedc']"], ["//li[@data-pk='covid_sivic']"], ["//li[@data-pk='covid_sivic']"], ["//li[@data-pk='covid_sivic']"], ["//li[@data-pk='covid_sivic']"]]
data_pk_c_petit_family = [[["//div[@data-pk='covid_cedc_sex_heb.dc_elec_covid_cum']"], ["//div[@data-pk='covid_hospit.hosp']"]], 
                   [["//div[@data-pk='covid_hospit.rea']"]],
                   [["//div[@data-pk='sursaud_corona_quot.nbre_pass_corona']"]],
                   [["//div[@data-pk='covid_cedc_heb.dc_elec_covid_cum']"]], 
                    [["//div[@data-pk='covid_hospit_clage10.hosp']"]],
                    [["//div[@data-pk='covid_hospit_clage10.hosp']"]],
                    [["//div[@data-pk='covid_hospit_clage10.rea']"]],
                    [["//div[@data-pk='covid_hospit_clage10.rea']"]]]
par_family = [['hommes et femmes', 'hommes', 'femmes'], ['hommes et femmes', 'hommes', 'femmes'], ['tous âges', 'moins de 15 ans', '15-44 ans', '45-64 ans', '65-74 ans', '75 ans ou plus'], ['0-29 ans', '30-49 ans', '50-59 ans', '60-69 ans', '70-79 ans', '80-89 ans', '90 ans et plus'], ['0-9 ans', '10-19 ans', '20-29 ans', '30-39 ans', '40-49 ans', '50-59 ans', '60-69 ans'], ['70-79 ans', '80-89 ans', '90 ans et plus'], ['0-9 ans', '10-19 ans', '20-29 ans', '30-39 ans', '40-49 ans', '50-59 ans', '60-69 ans'], ['70-79 ans', '80-89 ans', '90 ans et plus']]
names = [['Nombre cumulé de décès', 'Nombre cumulé de décès - Hommes', 'Nombre cumulé de décès - Femmes', 'Nombre de personnes hospitalisées', 'Nombre de personnes hospitalisées - Hommes', 'Nombre de personnes hospitalisées - Femmes'],
        ['Nombre de personnes en réanimation', 'Nombre de personnes en réanimation - Hommes', 'Nombre de personnes en réanimation - Femmes'],
        ['Nombre de passages COVID-19 quotidien aux urgences', 'Nombre de passages COVID-19 quotidien aux urgences - moins de 15 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 15-44 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 45-64 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 65-74 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 75 ans ou plus'],
        ['Nombre cumulé de décès - 0-29 ans', 'Nombre cumulé de décès - 30-49 ans', 'Nombre cumulé de décès - 50-59 ans', 'Nombre cumulé de décès - 60-79 ans', 'Nombre cumulé de décès - 80-89 ans', 'Nombre cumulé de décès - 90 ans et plus'],
        ['Nombre de personnes hospitalisées - 0-9 ans', 'Nombre de personnes hospitalisées - 10-19 ans', 'Nombre de personnes hospitalisées - 20-29 ans' 'Nombre de personnes hospitalisées - 30-39 ans', 'Nombre de personnes hospitalisées - 40-49 ans', 'Nombre de personnes hospitalisées - 50-59 ans', 'Nombre de personnes hospitalisées - 60-69 ans'],
        ['Nombre de personnes hospitalisées - 70-79 ans', 'Nombre de personnes hospitalisées - 80-89 ans', 'Nombre de personnes hospitalisées - 90 ans et plus'],
        ['Nombre de personnes en réanimation - 0-9 ans', 'Nombre de personnes en réanimation - 10-19 ans', 'Nombre de personnes en réanimation - 20-29 ans' 'Nombre de personnes en réanimation - 30-39 ans', 'Nombre de personnes en réanimation - 40-49 ans', 'Nombre de personnes en réanimation - 50-59 ans', 'Nombre de personnes en réanimation - 60-69 ans'],
        ['Nombre de personnes en réanimation - 70-79 ans', 'Nombre de personnes en réanimation - 80-89 ans', 'Nombre de personnes en réanimation - 90 ans et plus']]

# %%
len(names)
# Out:
# 8

# %%
for i in range(len(data_pk_c_moyen_family)):
    scrap(data_pk_c_moyen_family[i], data_pk_c_petit_family[i], par_family[i])
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-520-77bb5cadc1c2> in <module>()
#       1 for i in range(len(data_pk_c_moyen_family)):
# ----> 2     scrap(data_pk_c_moyen_family[i], data_pk_c_petit_family[i], par_family[i])
#
# <ipython-input-519-93830ccddca8> in scrap(data_pk_c_moyen, data_pk_c_petit, par)
#      20                 time.sleep(2)
#      21         if i == len(data_pk_c_moyen) - 1:
# ---> 22             ActionChains(driver).move_to_element(driver.find_element_by_xpath("//span[@class='removeAllItems hide-iframe']")).click().perform()
#      23         time.sleep(2)
#      24         zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/action_chains.py in perform(self)
#      78         """
#      79         if self._driver.w3c:
# ...

# %%
driver.find_element_by_xpath("//div[@data-pk='patho_c']").click()
time.sleep(1)

driver.find_element_by_xpath("//li[@data-pk='covid']").click()
time.sleep(2)

for i in range(len(data_pk_c_moyen)):
    driver.find_element_by_xpath(data_pk_c_moyen[i]).click()
    time.sleep(2)
    for j in range(len(data_pk_c_petit[i])):
        driver.find_element_by_xpath(data_pk_c_petit[i][j]).click()
        time.sleep(2)
        for k in range(len(par)):
            ActionChains(driver).move_to_element(driver.find_element_by_link_text(par[k])).click().perform()
            #driver.find_element_by_link_text(par([k]).click()
            time.sleep()
    zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
    ActionChains(driver).move_to_element(zone_retour.find_element_by_link_text('COVID-19')).click().perform()

# %%
driver = webdriver.Firefox()

driver.get("https://geodes.santepubliquefrance.fr/#c=indicator&view=map2")
time.sleep(5)
    
driver.find_element_by_xpath("//a[@id='tm_table']").click()
time.sleep(2)
    
driver.find_element_by_xpath("//div[@data-pk='patho_c']").click()
time.sleep(2)
    
driver.find_element_by_xpath("//li[@data-pk='covid']").click()
time.sleep(2)

DF = []

for p in range(len(data_pk_c_moyen_family)):
    data_pk_c_moyen = data_pk_c_moyen_family[p]
    data_pk_c_petit = data_pk_c_petit_family[p]
    par = par_family[p]
    print(par)
    for i in range(len(data_pk_c_moyen)):
        ActionChains(driver).move_to_element(driver.find_element_by_xpath(data_pk_c_moyen[i])).click().perform()
        #driver.find_element_by_xpath(data_pk_c_moyen[i]).click()
        time.sleep(2)
        for j in range(len(data_pk_c_petit[i])):
            #zone_gauche = driver.find_element_by_xpath("//div[@class='ui-collapsible-set vertical-scrollable indic-container']")
            driver.execute_script("arguments[0].scrollIntoView();", driver.find_element_by_xpath(data_pk_c_petit[i][j]))
            time.sleep(1)
            #ActionChains(driver).move_to_element(driver.find_element_by_xpath(data_pk_c_petit[i][j])).click().perform()
            driver.find_element_by_xpath(data_pk_c_petit[i][j]).click()
            time.sleep(2)
            for k in range(len(par)):
                driver.execute_script("arguments[0].scrollIntoView();", driver.find_element_by_link_text(par[k]))
                time.sleep(1)
                ActionChains(driver).move_to_element(driver.find_element_by_link_text(par[k])).click().perform()
                #driver.find_element_by_link_text(par([k])).click()
                time.sleep(3)
        zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
        driver.execute_script("arguments[0].scrollIntoView();", zone_retour.find_element_by_link_text('COVID-19'))
        time.sleep(1)
        ActionChains(driver).move_to_element(zone_retour.find_element_by_link_text('COVID-19')).click().perform()
        time.sleep(2)
        
    L = []
    Table = driver.find_element_by_xpath("//tbody")
    Rows = Table.find_elements_by_xpath("//tr")
    for row in Rows:
        Cells = row.find_elements_by_tag_name('td')
        L.append([cell.text for cell in Cells])
    driver.find_element_by_xpath("//li[@data-pk='covid_cedc']").click()
    time.sleep(2)
    ActionChains(driver).move_to_element(driver.find_element_by_xpath("//span[@class='removeAllItems hide-iframe']")).click().perform()
    time.sleep(2)
    zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
    ActionChains(driver).move_to_element(zone_retour.find_element_by_link_text('COVID-19')).click().perform()
    time.sleep(2)
    data = L[16 : len(L) - 2]
    
    DF.append(pd.DataFrame(data, columns = ['Code', 'Libellé'] + names[p]))
# Out:
# ['hommes et femmes', 'hommes', 'femmes']
# ['hommes et femmes', 'hommes', 'femmes']
# ['tous âges', 'moins de 15 ans', '15-44 ans', '45-64 ans', '65-74 ans', '75 ans ou plus']
# ['0-29 ans', '30-49 ans', '50-59 ans', '60-69 ans', '70-79 ans', '80-89 ans', '90 ans et plus']
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-616-cbde27a3d6e6> in <module>()
#      32             time.sleep(2)
#      33             for k in range(len(par)):
# ---> 34                 driver.execute_script("arguments[0].scrollIntoView();", driver.find_element_by_link_text(par[k]))
#      35                 time.sleep(1)
#      36                 ActionChains(driver).move_to_element(driver.find_element_by_link_text(par[k])).click().perform()
#
# /anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_link_text(self, link_text)
# ...

# %%
DF[0]
# Out:
#     Code                            Libellé         Nombre cumulé de décès  \
# 0     01                                Ain                            225
# 1     02                              Aisne                             69
# 2     03                             Allier                            139
# 3     04            Alpes-de-Haute-Provence                             14
# 4     05                       Hautes-Alpes                             46
# 5     06                    Alpes-Maritimes                            272
# 6     07                            Ardèche                            161
# 7     08                           Ardennes                              0
# 8     09                             Ariège                             10
# 9     10                               Aube                             57
# 10    11                               Aude                             70
# ...

# %% [markdown]
# ## Données INSEE

# %% [markdown]
# Estimation de la population (2020)
# Surface des départements pour avoir une densité de population
# Taux brut de mortalité (2019)
# Taille moyenne des ménages (2017)
# Taux de pauvreté (2017)
# Part des résidences principales suroccupées (2016)
# Part postes du commerce, transport et services marchands (2015)
# Moyen de transport utilisé pour se rendre au travail - transport en commun (2017)
# Flux domicile - lieu de travail (2017) mais c'est compliqué parce qu'il y a le département de départ et celui d'arrivée
# Vente de cigarettes par habitant de 15 à 74 ans (2013) https://odicer.ofdt.fr/mobile.php#ficindic

# %%
import time
import requests
import pandas as pd
from selenium import webdriver
import geckodriver_autoinstaller


geckodriver_autoinstaller.install()  # Check if the current version of geckodriver exists
                                     # and if it doesn't exist, download it automatically,
                                     # then add geckodriver to path

driver = webdriver.Firefox()

driver.get('https://statistiques-locales.insee.fr/#c=indicator&view=map2')
time.sleep(15)

# %%
onglet = ['MOGRAPHIE', 'CONSOMMATION', 'CONDITIONS', 'ENTREPRISES']
data_pk_gros = ["//div[@data-pk='demo_d']", "//div[@data-pk='revenus_d']", "//div[@data-pk='vie_societe_d']", "//div[@data-pk='entreprise_d']"]
data_pk_moyen = [["//li[@data-pk='evo_stru_pop']", "//li[@data-pk='deces']", "//li[@data-pk='couples']"], ["//li[@data-pk='pauv_prec']"], ["//li[@data-pk='log']"], ["//li[@data-pk='carac_entrp']"]]
data_pk_petit = [[["//div[@data-pk='tcrd021.estim_pop_ensemble']"], ["//div[@data-pk='tcrd048.txbrut_mort']"], ["//div[@data-pk='bdcom.taille_menage']"]],
                 [["//div[@data-pk='filosofi.tp60']"]],
                 [["//div[@data-pk='suroccupation.suroccup']"]],
                 [["//div[@data-pk='clap.pt_etpgu_dans_etptot']"]]]

# %%
driver.find_element_by_xpath("//a[@id='tm_table']").click()
time.sleep(1)

for i in range(len(data_pk_gros)):
    driver.find_element_by_xpath(data_pk_gros[i]).click()
    time.sleep(1)
    for j in range(len(data_pk_moyen[i])):
        driver.find_element_by_xpath(data_pk_moyen[i][j]).click()
        time.sleep(1)
        for k in range(len(data_pk_petit[i][j])):
            driver.find_element_by_xpath(data_pk_petit[i][j][k]).click()
            time.sleep(1)
        zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
        zone_retour.find_element_by_partial_link_text(onglet[i]).click()

# %%
# On récupère le tableau

L = []

Table = driver.find_element_by_xpath("//tbody")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data = L[16 : len(L) - 2]

# %%
L
# Out:
# [['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  [],
#  [],
#  [],
#  [],
#  ['01', 'Ain', '656\u202f955', '7,6', '2,3', '10,5', '2,4', '37,3'],
#  ['02', 'Aisne', '526\u202f050', '11,1', '2,3', '18,5', '2,4', '34,9'],
#  ['03', 'Allier', '331\u202f315', '13,6', '2,0', '15,4', '1,6', '36,0'],
#  ['04',
#   'Alpes-de-Haute-Provence',
#   '165\u202f197',
#   '11,9',
#   '2,1',
#   '16,6',
#   '3,1',
#   '39,2'],
#  ['05', 'Hautes-Alpes', '141\u202f756', '10,4', '2,1', '13,9', '2,8', '46,4'],
#  ['06',
#   'Alpes-Maritimes',
#   '1\u202f079\u202f396',
#   '11,0',
#   '2,1',
#   '15,5',
#   '11,7',
#   '52,5'],
#  ['07', 'Ardèche', '326\u202f875', '11,6', '2,2', '14,3', '1,9', '29,9'],
#  ['08', 'Ardennes', '265\u202f531', '11,1', '2,2', '18,9', '1,5', '31,0'],
#  ['09', 'Ariège', '152\u202f398', '12,9', '2,1', '18,4', '2,2', '32,3'],
# ...

# %%
df = pd.DataFrame(data, columns = ['Code', 'Libellé', 'Estimation de la population (2020)', 'Taux brut de mortalité (2019)', 'Taille moyenne des ménages (2017)', 'Taux de pauvreté (2017)', 'Part des résidences principales suroccupées (2016)', 'Part postes du commerce, transport et services marchands (2015)'])
df.set_index('Code',inplace=True)
df
# Out:
#                       Libellé Estimation de la population (2020)  \
# Code
# 01                        Ain                            656 955
# 02                      Aisne                            526 050
# 03                     Allier                            331 315
# 04    Alpes-de-Haute-Provence                            165 197
# 05               Hautes-Alpes                            141 756
# 06            Alpes-Maritimes                          1 079 396
# 07                    Ardèche                            326 875
# 08                   Ardennes                            265 531
# 09                     Ariège                            152 398
# 10                       Aube                            309 907
# 11                       Aude                            372 705
# 12                    Aveyron                            278 360
# 13           Bouches-du-Rhône                          2 034 469
# ...

# %%
driver.find_element_by_xpath("//span[@class='removeAllItems hide-iframe']").click()
time.sleep(1)

# On clique sur l'onglet démographie
driver.find_element_by_xpath("//div[@data-pk='terr_d']").click()
time.sleep(1)

# Puis sur évolution et structure de la population
driver.find_element_by_xpath("//li[@data-pk='mobilites']").click()
time.sleep(1)

# Et enfin sur estimations de population, 2020
driver.find_element_by_xpath("//div[@data-pk='rp.rep_actocc15p_mode_transp']").click()
time.sleep(1)

Table = driver.find_element_by_xpath("//tbody")
Row = Table.find_element_by_xpath("//tr")
Cells = Row.find_elements_by_xpath("//td[8]")
data1 = [cell.text for cell in Cells]

# %%
df['Moyen de transport utilisé pour se rendre au travail - transport en commun (2017)'] = data1
df
# Out:
#                       Libellé Estimation de la population (2020)  \
# Code
# 01                        Ain                            656 955
# 02                      Aisne                            526 050
# 03                     Allier                            331 315
# 04    Alpes-de-Haute-Provence                            165 197
# 05               Hautes-Alpes                            141 756
# 06            Alpes-Maritimes                          1 079 396
# 07                    Ardèche                            326 875
# 08                   Ardennes                            265 531
# 09                     Ariège                            152 398
# 10                       Aube                            309 907
# 11                       Aude                            372 705
# 12                    Aveyron                            278 360
# 13           Bouches-du-Rhône                          2 034 469
# ...

# %%
driver = webdriver.Firefox()

driver.get('https://odicer.ofdt.fr/mobile.php#ficindic')
time.sleep(5)

driver.find_element_by_xpath("//li[@id='mr003']").click()
time.sleep(3)

driver.find_element_by_xpath("//li[@id='iliad.tx_cig']").click()
time.sleep(3)

driver.find_element_by_xpath("//a[@id='tableNivgeo_lk']").click()
time.sleep(1)

driver.find_element_by_xpath("//li[@data-nivgeo='dep']").click()
time.sleep(1)

# %%
L = []
Table = driver.find_element_by_xpath("//div[@id='fincIndicBlocD']")
Rows = Table.find_elements_by_tag_name('g')
for row in Rows:
    Cells = row.find_elements_by_tag_name('text')
    for cell in Cells:
        L.append(cell.text)
        
data2 = L[44:]

# %%
df2 = pd.DataFrame()
df2['Département'] = [data2[2 * i] for i in range(len(data2) // 2)]
df2 = pd.DataFrame(df2['Département'].str.split(' - ',1).tolist(), columns = ['Code', 'Libellé'])
df2['Vente de cigarettes par habitant de 15 à 74 ans (2013)'] = [data2[2 * i + 1] for i in range(len(data2) // 2)]

# On retire les lignes identiques
df2.drop_duplicates(inplace = True)

# On retire la colonne Libellé car on l'a déjà dans df
df2.drop('Libellé', axis = 1, inplace = True)

# On retire les dernières car elles sont vides et leur code est difficile à gérer
df2.drop([188, 190, 192, 194, 196, 198, 200], inplace = True)

# On remet les codes dans l'ordre
df2['Code'].astype('int')
df2.sort_values(by = 'Code', inplace = True)

df2.set_index('Code', inplace = True)

df2
# Out:
#      Vente de cigarettes par habitant de 15 à 74 ans (2013)
# Code
# 01                                              1 003,9
# 02                                                846,9
# 03                                              1 117,6
# 04                                              1 349,8
# 05                                              1 153,7
# 06                                              1 413,8
# 07                                              1 019,3
# 08                                                498,2
# 09                                                653,4
# 10                                              1 074,4
# 11                                              1 032,8
# 12                                                982,1
# 13                                              1 402,0
# 14                                              1 192,0
# 15                                              1 172,6
# 16                                              1 071,9
# ...

# %%
df['Vente de cigarettes par habitant de 15 à 74 ans (2013)'] = df2['Vente de cigarettes par habitant de 15 à 74 ans (2013)']
df
# Out:
#                       Libellé Estimation de la population (2020)  \
# Code
# 01                        Ain                            656 955
# 02                      Aisne                            526 050
# 03                     Allier                            331 315
# 04    Alpes-de-Haute-Provence                            165 197
# 05               Hautes-Alpes                            141 756
# 06            Alpes-Maritimes                          1 079 396
# 07                    Ardèche                            326 875
# 08                   Ardennes                            265 531
# 09                     Ariège                            152 398
# 10                       Aube                            309 907
# 11                       Aude                            372 705
# 12                    Aveyron                            278 360
# 13           Bouches-du-Rhône                          2 034 469
# ...

# %%
driver = webdriver.Firefox()

driver.get('https://fr.wikipedia.org/wiki/Superficie_des_d%C3%A9partements_fran%C3%A7ais')
time.sleep(1)

# %%
Table = driver.find_element_by_xpath("//tbody")
Row = Table.find_element_by_xpath("//tr")
Cells = Row.find_elements_by_xpath("//td[7]")
Res = [cell.text for cell in Cells]

# %%
# Il faut replacer la Corse
temp = Res[1: 20] + Res[21: 30]
temp.append(Res[20])
temp.append('4 666Insee 21')
data3 = temp + Res[30: len(Res)]

# Il manque Mayotte
data3.append('')

len(data3)
# Out:
# 101

# %%
df3 = pd.DataFrame(data3, columns = ['Superficie'])
df3 = pd.DataFrame(df3['Superficie'].str.split('Insee ',1).tolist(), columns = ['Superficie', 'Chiffres'])
df3.index = df.index

df['Superficie'] = df3['Superficie']
df
# Out:
#                       Libellé Estimation de la population (2020)  \
# Code
# 01                        Ain                            656 955
# 02                      Aisne                            526 050
# 03                     Allier                            331 315
# 04    Alpes-de-Haute-Provence                            165 197
# 05               Hautes-Alpes                            141 756
# 06            Alpes-Maritimes                          1 079 396
# 07                    Ardèche                            326 875
# 08                   Ardennes                            265 531
# 09                     Ariège                            152 398
# 10                       Aube                            309 907
# 11                       Aude                            372 705
# 12                    Aveyron                            278 360
# 13           Bouches-du-Rhône                          2 034 469
# ...

# %%
geojson_france_url = "https://france-geojson.gregoiredavid.fr/repo/departements.geojson"
geojson_france = requests.get(geojson_france_url).json()
geo_data = pd.DataFrame(geojson_france)
geo_data
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 1   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 2   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 3   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 4   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 5   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 6   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 7   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 8   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 9   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 10  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 11  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# ...
