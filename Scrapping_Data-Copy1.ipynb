# %% [markdown]
# # Initialisation

# %%
import time
import requests
import pandas as pd
from selenium import webdriver
#import geckodriver_autoinstaller
from selenium.webdriver.common.action_chains import ActionChains

#geckodriver_autoinstaller.install()

from selenium.webdriver.common.keys import Keys #la classe keus permet d'utiliser les touches du clavier
from selenium.webdriver import Chrome
import pandas as pd

# %% [markdown]
# Importation données temporelles maladies

# %%
onglet = ['A','B', 'G','O', 'P']
data_pk_gros = ["//div[@data-pk='patho_a']","//div[@data-pk='patho_b']","//div[@data-pk='patho_g']", "//div[@data-pk='patho_o']", "//div[@data-pk='patho_p']"]

data_pk_moyen = [["//li[@data-pk='asthme']","//li[@data-pk='allergie']" ],["//li[@data-pk='bronchite']" ],["//li[@data-pk='grippe']"], ["//li[@data-pk='orl']"], ["//li[@data-pk='pneumo']"]]

data_pk_petit = [[["//div[@data-pk='sursaud_sau.prop_asthme_hospit_sau']"],["//div[@data-pk='sursaud_sau.prop_allergie_hospit_sau']"]],[["//div[@data-pk='sursaud_sau.prop_bronchite_hospit_sau']"]],
                 [["//div[@data-pk='sursaud_sau.prop_grippe_hospi_sau']"]],[["//div[@data-pk='sursaud_sau.prop_orl_hospit_sau']"]],
                 [["//div[@data-pk='sursaud_sau.prop_pneumo_hospit_sau']"]]]

# %%
driver = webdriver.Chrome("/Users/antoineloubeyre/Downloads/chromedriver-5")


driver.get("https://geodes.santepubliquefrance.fr/#c=indicator&view=map2")
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_table']").click()
time.sleep(2)


for i in range(len(data_pk_gros)):
    driver.find_element_by_xpath(data_pk_gros[i]).click()
    time.sleep(1)
    for j in range(len(data_pk_moyen[i])):
        driver.find_element_by_xpath(data_pk_moyen[i][j]).click()
        time.sleep(1)
        for k in range(len(data_pk_petit[i][j])):
            driver.find_element_by_xpath(data_pk_petit[i][j][k]).click()
            time.sleep(1)
        driver.find_element_by_link_text('tous âges').click()
        time.sleep(1)
        zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
        ActionChains(driver).move_to_element(zone_retour.find_element_by_link_text(onglet[i])).click().perform()
        #zone_retour.find_element_by_link_text(onglet[i]).click() #J'ai dû écrire la ligne du dessus à la place c'est un pb propre à mon ordi

# %%
driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_asthme = L[593: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()


L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_allergie = L[593 : len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()


L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_bronchite = L[593 : len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()


L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_grippe = L[593 : len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()


L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_orl = L[593 : len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()


L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_pneumo = L[593 : len(L) ]

# %%
df_asthme = pd.DataFrame(data_asthme, columns = ['Date', 'Asthme'])
df_allergie = pd.DataFrame(data_allergie, columns = ['Date', 'allergie'])
df_bronchite = pd.DataFrame(data_asthme, columns = ['Date', 'bronchite'])
df_grippe = pd.DataFrame(data_grippe, columns = ['Date', 'grippe'])
df_orl = pd.DataFrame(data_orl, columns = ['Date', 'Orl'])
df_pneumo = pd.DataFrame(data_pneumo, columns = ['Date', 'Pneumo'])

# %%
df_asthme["Asthme"].replace(' ', '', regex=True, inplace=True)
df2_asthme=df_asthme["Asthme"].astype(float)
df2_asthme=df2_asthme.to_frame()
df_asthme.drop(columns='Asthme',inplace=True)
df_asthme=pd.concat([df_asthme,df2_asthme], axis=1)

df_allergie["allergie"].replace(' ', '', regex=True, inplace=True)
df2_allergie=df_allergie["allergie"].astype(float)
df2_allergie=df2_allergie.to_frame()
df_allergie.drop(columns='allergie',inplace=True)
df_allergie=pd.concat([df_allergie,df2_allergie], axis=1)
df_allergie.drop(columns='Date',inplace=True)

df_bronchite["bronchite"].replace(' ', '', regex=True, inplace=True)
df2_bronchite=df_bronchite["bronchite"].astype(float)
df2_bronchite=df2_bronchite.to_frame()
df_bronchite.drop(columns='bronchite',inplace=True)
df_bronchite=pd.concat([df_bronchite,df2_bronchite], axis=1)
df_bronchite.drop(columns='Date',inplace=True)

df_grippe["grippe"].replace(',', '', regex=True, inplace=True)
df_grippe["grippe"].replace(' ', '', regex=True, inplace=True)
df2_grippe=df_grippe["grippe"].astype(float)
df2_grippe=df2_grippe.to_frame()
df_grippe.drop(columns='grippe',inplace=True)
df_grippe=pd.concat([df_grippe,df2_grippe], axis=1)
df_grippe.drop(columns='Date',inplace=True)

df_orl["Orl"].replace(' ', '', regex=True, inplace=True)
df2_orl=df_orl["Orl"].astype(float)
df2_orl=df2_orl.to_frame()
df_orl.drop(columns='Orl',inplace=True)
df_orl=pd.concat([df_orl,df2_orl], axis=1)
df_orl.drop(columns='Date',inplace=True)

df_pneumo["Pneumo"].replace(' ', '', regex=True, inplace=True)
df2_pneumo=df_pneumo["Pneumo"].astype(float)
df2_pneumo=df2_pneumo.to_frame()
df_pneumo.drop(columns='Pneumo',inplace=True)
df_pneumo=pd.concat([df_pneumo,df2_pneumo], axis=1)
df_pneumo.drop(columns='Date',inplace=True)


df_maladie=pd.concat([df_asthme,df_allergie,df_bronchite, df_grippe,df_orl, df_pneumo ], axis=1)

# %%
df_maladie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573 entries, 0 to 572
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       572 non-null    object
#  1   Asthme     572 non-null    float64
#  2   allergie   572 non-null    float64
#  3   bronchite  572 non-null    float64
#  4   grippe     572 non-null    float64
#  5   Orl        572 non-null    float64
#  6   Pneumo     572 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 31.5+ KB

# %%
df_maladie.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/maladie.csv', index = False, header=True)

# %% [markdown]
# Importation données Covid-19

# %%
data_pk_c_moyen_family = [["//li[@data-pk='covid_cedc']", "//li[@data-pk='covid_sivic']"], ["//li[@data-pk='covid_sivic']"], ["//li[@data-pk='covid_oscour']"]]
data_pk_c_petit_family = [[["//div[@data-pk='covid_cedc_sex_heb.dc_elec_covid_cum']"], ["//div[@data-pk='covid_hospit.hosp']"]], 
                   [["//div[@data-pk='covid_hospit.rea']"]],
                   [["//div[@data-pk='sursaud_corona_quot.nbre_pass_corona']"]]]
par_family = [['hommes et femmes', 'hommes', 'femmes'], ['hommes et femmes', 'hommes', 'femmes'], ['tous âges', 'moins de 15 ans', '15-44 ans', '45-64 ans', '65-74 ans', '75 ans ou plus']]
names = [['Nombre cumulé de décès', 'Nombre cumulé de décès - Hommes', 'Nombre cumulé de décès - Femmes', 'Nombre de personnes hospitalisées', 'Nombre de personnes hospitalisées - Hommes', 'Nombre de personnes hospitalisées - Femmes'],
        ['Nombre de personnes en réanimation', 'Nombre de personnes en réanimation - Hommes', 'Nombre de personnes en réanimation - Femmes'],
        ['Nombre de passages COVID-19 quotidien aux urgences', 'Nombre de passages COVID-19 quotidien aux urgences - moins de 15 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 15-44 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 45-64 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 65-74 ans', 'Nombre de passages COVID-19 quotidien aux urgences - 75 ans ou plus']]

# %%
driver = webdriver.Chrome("/Users/antoineloubeyre/Downloads/chromedriver-5")


driver.get("https://geodes.santepubliquefrance.fr/#c=indicator&view=map2")
time.sleep(5)
    
driver.find_element_by_xpath("//a[@id='tm_table']").click()
time.sleep(2)
    
driver.find_element_by_xpath("//div[@data-pk='patho_c']").click()
time.sleep(2)
    
driver.find_element_by_xpath("//li[@data-pk='covid']").click()
time.sleep(2)

DF = []

for p in range(len(data_pk_c_moyen_family)):
    print(p)
    data_pk_c_moyen = data_pk_c_moyen_family[p]
    data_pk_c_petit = data_pk_c_petit_family[p]
    par = par_family[p]
    for i in range(len(data_pk_c_moyen)):
        ActionChains(driver).move_to_element(driver.find_element_by_xpath(data_pk_c_moyen[i])).click().perform()
        #driver.find_element_by_xpath(data_pk_c_moyen[i]).click()
        time.sleep(2)
        for j in range(len(data_pk_c_petit[i])):
            #zone_gauche = driver.find_element_by_xpath("//div[@class='ui-collapsible-set vertical-scrollable indic-container']")
            driver.execute_script("arguments[0].scrollIntoView();", driver.find_element_by_xpath(data_pk_c_petit[i][j]))
            time.sleep(1)
            #ActionChains(driver).move_to_element(driver.find_element_by_xpath(data_pk_c_petit[i][j])).click().perform()
            driver.find_element_by_xpath(data_pk_c_petit[i][j]).click()
            time.sleep(2)
            for k in range(len(par)):
                driver.execute_script("arguments[0].scrollIntoView();", driver.find_element_by_link_text(par[k]))
                time.sleep(1)
                ActionChains(driver).move_to_element(driver.find_element_by_link_text(par[k])).click().perform()
                #driver.find_element_by_link_text(par[k]).click()
                time.sleep(2)
        zone_retour = driver.find_element_by_xpath("//div[@class='ui-collapset-header mtn mbvs']")
        driver.execute_script("arguments[0].scrollIntoView();", zone_retour.find_element_by_link_text('COVID-19'))
        time.sleep(1)
        ActionChains(driver).move_to_element(zone_retour.find_element_by_link_text('COVID-19')).click().perform()
        time.sleep(2)
# Out:
# 0
# 1
# 2

# %%
driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_mort_cum_C19 = L[ 40: len(L) ]

# %%
print(data_mort_cum_C19)
# Out:
# [['2020-S10', '7'], ['2020-S11', '94'], ['2020-S12', '523'], ['2020-S13', '1 746'], ['2020-S14', '3 766'], ['2020-S15', '5 765'], ['2020-S16', '7 459'], ['2020-S17', '8 613'], ['2020-S18', '9 391'], ['2020-S19', '9 965'], ['2020-S20', '10 338'], ['2020-S21', '10 632'], ['2020-S22', '10 834'], ['2020-S23', '10 972'], ['2020-S24', '11 065'], ['2020-S25', '11 127'], ['2020-S26', '11 169'], ['2020-S27', '11 204'], ['2020-S28', '11 228'], ['2020-S29', '11 262'], ['2020-S30', '11 297'], ['2020-S31', '11 330'], ['2020-S32', '11 362'], ['2020-S33', '11 413'], ['2020-S34', '11 461'], ['2020-S35', '11 519'], ['2020-S36', '11 585'], ['2020-S37', '11 719'], ['2020-S38', '11 918'], ['2020-S39', '12 126'], ['2020-S40', '12 378'], ['2020-S41', '12 668'], ['2020-S42', '13 144'], ['2020-S43', '13 944'], ['2020-S44', '15 314'], ['2020-S45', '17 050'], ['2020-S46', '18 847'], ['2020-S47', '20 552'], ['2020-S48', '22 044']]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_mort_cum_C19_H = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_mort_cum_C19_F = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_hostpi_C19 = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_hostpi_C19_H = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_hostpi_C19_F = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19 = L[ 40: len(L)]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_H = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_F = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_suspicion = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_suspicion_15ans = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_suspicion_15_44 = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_suspicion_45_64 = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_suspicion_65_74 = L[ 40: len(L) ]

# %%
driver.find_element_by_xpath("//button[@class='right mrs arrow-h2']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@id='tm_fiche']").click()
time.sleep(2)

driver.find_element_by_xpath("//a[@class='grille no-print']").click()
time.sleep(2)

driver.find_element_by_link_text('Données').click()

L = []

Table = driver.find_element_by_xpath("//table[@class='ui-table-reflow mbvs']")
Rows = Table.find_elements_by_xpath("//tr")
for row in Rows:
    Cells = row.find_elements_by_tag_name('td')
    L.append([cell.text for cell in Cells])

data_rea_C19_suspicion_75 = L[ 40: len(L) ]

# %%
df_mort_cum_C19 = pd.DataFrame(data_mort_cum_C19, columns = ['Date', 'mort_cum_C19'])
df_mort_cum_C19_H = pd.DataFrame(data_mort_cum_C19_H, columns = ['Date', 'mort_cum_C19_H'])
df_mort_cum_C19_F = pd.DataFrame(data_mort_cum_C19_F, columns = ['Date', 'mort_cum_C19_F'])

df_hostpi_C19 = pd.DataFrame(data_hostpi_C19, columns = ['Date', 'hostpi_C19'])
df_hostpi_C19_H = pd.DataFrame(data_hostpi_C19_H, columns = ['Date', 'hostpi_C19_H'])
df_hostpi_C19_F = pd.DataFrame(data_hostpi_C19_F, columns = ['Date', 'hostpi_C19_F'])

df_rea_C19 = pd.DataFrame(data_rea_C19, columns = ['Date', 'rea_C19'])
df_rea_C19_H = pd.DataFrame(data_rea_C19_H, columns = ['Date', 'rea_C19_H'])
df_rea_C19_F = pd.DataFrame(data_rea_C19_F, columns = ['Date', 'rea_C19_F'])

df_rea_C19_suspicion = pd.DataFrame(data_rea_C19_suspicion, columns = ['Date', 'rea_C19_suspicion'])
df_rea_C19_suspicion_15ans = pd.DataFrame(data_rea_C19_suspicion_15ans, columns = ['Date', 'rea_C19_suspicion_15ans'])
df_rea_C19_suspicion_15_44 = pd.DataFrame(data_rea_C19_suspicion_15_44, columns = ['Date', 'rea_C19_suspicion_15_44'])
df_rea_C19_suspicion_45_64 = pd.DataFrame(data_rea_C19_suspicion_45_64, columns = ['Date', 'rea_C19_suspicion_45_64'])
df_rea_C19_suspicion_65_74 = pd.DataFrame(data_rea_C19_suspicion_65_74, columns = ['Date', 'rea_C19_suspicion_65_74'])
df_rea_C19_suspicion_75 = pd.DataFrame(data_rea_C19_suspicion_75, columns = ['Date', 'rea_C19_suspicion_75'])

# %%
df_mort_cum_C19["mort_cum_C19"].replace(' ', '', regex=True, inplace=True)
df2_mort_cum_C19=df_mort_cum_C19["mort_cum_C19"].astype(float)
df2_mort_cum_C19=df2_mort_cum_C19.to_frame()
df_mort_cum_C19.drop(columns='mort_cum_C19',inplace=True)
df_mort_cum_C19=pd.concat([df_mort_cum_C19,df2_mort_cum_C19], axis=1)
#df_mort_cum_C19=pd.concat([df_mort_cum_C19,df2_mort_cum_C19], axis=1)


df_mort_cum_C19_H["mort_cum_C19_H"].replace(' ', '', regex=True, inplace=True)
df2_mort_cum_C19_H=df_mort_cum_C19_H["mort_cum_C19_H"].astype(float)
df2_mort_cum_C19_H=df2_mort_cum_C19_H.to_frame()
df_mort_cum_C19_H.drop(columns='mort_cum_C19_H',inplace=True)
df_mort_cum_C19_H=pd.concat([df_mort_cum_C19_H,df2_mort_cum_C19_H], axis=1)
#df_mort_cum_C19_H.drop(columns='Date',inplace=True)


df_mort_cum_C19_F["mort_cum_C19_F"].replace(' ', '', regex=True, inplace=True)
df2_mort_cum_C19_F=df_mort_cum_C19_F["mort_cum_C19_F"].astype(float)
df2_mort_cum_C19_F=df2_mort_cum_C19_F.to_frame()
df_mort_cum_C19_F.drop(columns='mort_cum_C19_F',inplace=True)
df_mort_cum_C19_F=pd.concat([df_mort_cum_C19_F,df2_mort_cum_C19_F], axis=1)
#df_mort_cum_C19_F.drop(columns='Date',inplace=True)





df_hostpi_C19["hostpi_C19"].replace(' ', '', regex=True, inplace=True)
df2_hostpi_C19=df_hostpi_C19["hostpi_C19"].astype(float)
df2_hostpi_C19=df2_hostpi_C19.to_frame()
df_hostpi_C19.drop(columns='hostpi_C19',inplace=True)
df_hostpi_C19=pd.concat([df_hostpi_C19,df2_hostpi_C19], axis=1)
#df_hostpi_C19.drop(columns='Date',inplace=True)

df_hostpi_C19_H["hostpi_C19_H"].replace(' ', '', regex=True, inplace=True)
df2_hostpi_C19_H=df_hostpi_C19_H["hostpi_C19_H"].astype(float)
df2_hostpi_C19_H=df2_hostpi_C19_H.to_frame()
df_hostpi_C19_H.drop(columns='hostpi_C19_H',inplace=True)
df_hostpi_C19_H=pd.concat([df_hostpi_C19_H,df2_hostpi_C19_H], axis=1)
#df_hostpi_C19_H.drop(columns='Date',inplace=True)

df_hostpi_C19_F["hostpi_C19_F"].replace(' ', '', regex=True, inplace=True)
df2_hostpi_C19_F=df_hostpi_C19_F["hostpi_C19_F"].astype(float)
df2_hostpi_C19_F=df2_hostpi_C19_F.to_frame()
df_hostpi_C19_F.drop(columns='hostpi_C19_F',inplace=True)
df_hostpi_C19_F=pd.concat([df_hostpi_C19_F,df2_hostpi_C19_F], axis=1)
#df_hostpi_C19_F.drop(columns='Date',inplace=True)

df_rea_C19["rea_C19"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19=df_rea_C19["rea_C19"].astype(float)
df2_rea_C19=df2_rea_C19.to_frame()
df_rea_C19.drop(columns='rea_C19',inplace=True)
df_rea_C19=pd.concat([df_rea_C19,df2_rea_C19], axis=1)
#df_rea_C19.drop(columns='Date',inplace=True)

df_rea_C19_H["rea_C19_H"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_H=df_rea_C19_H["rea_C19_H"].astype(float)
df2_rea_C19_H=df2_rea_C19_H.to_frame()
df_rea_C19_H.drop(columns='rea_C19_H',inplace=True)
df_rea_C19_H=pd.concat([df_rea_C19_H,df2_rea_C19_H], axis=1)
#df_rea_C19_H.drop(columns='Date',inplace=True)


df_rea_C19_F["rea_C19_F"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_F=df_rea_C19_F["rea_C19_F"].astype(float)
df2_rea_C19_F=df2_rea_C19_F.to_frame()
df_rea_C19_F.drop(columns='rea_C19_F',inplace=True)
df_rea_C19_F=pd.concat([df_rea_C19_F,df2_rea_C19_F], axis=1)
#df_rea_C19_F.drop(columns='Date',inplace=True)






df_rea_C19_suspicion["rea_C19_suspicion"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_suspicion=df_rea_C19_suspicion["rea_C19_suspicion"].astype(float)
df2_rea_C19_suspicion=df2_rea_C19_suspicion.to_frame()
df_rea_C19_suspicion.drop(columns='rea_C19_suspicion',inplace=True)
df_rea_C19_suspicion=pd.concat([df_rea_C19_suspicion,df2_rea_C19_suspicion], axis=1)
#df_rea_C19_suspicion.drop(columns='Date',inplace=True)

df_rea_C19_suspicion_15ans["rea_C19_suspicion_15ans"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_suspicion_15ans=df_rea_C19_suspicion_15ans["rea_C19_suspicion_15ans"].astype(float)
df2_rea_C19_suspicion_15ans=df2_rea_C19_suspicion_15ans.to_frame()
df_rea_C19_suspicion_15ans.drop(columns='rea_C19_suspicion_15ans',inplace=True)
df_rea_C19_suspicion_15ans=pd.concat([df_rea_C19_suspicion_15ans,df2_rea_C19_suspicion_15ans], axis=1)
#df_rea_C19_suspicion_15ans.drop(columns='Date',inplace=True)


df_rea_C19_suspicion_15_44["rea_C19_suspicion_15_44"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_suspicion_15_44=df_rea_C19_suspicion_15_44["rea_C19_suspicion_15_44"].astype(float)
df2_rea_C19_suspicion_15_44=df2_rea_C19_suspicion_15_44.to_frame()
df_rea_C19_suspicion_15_44.drop(columns='rea_C19_suspicion_15_44',inplace=True)
df_rea_C19_suspicion_15_44=pd.concat([df_rea_C19_suspicion_15_44,df2_rea_C19_suspicion_15_44], axis=1)
#df_rea_C19_suspicion_15_44.drop(columns='Date',inplace=True)

df_rea_C19_suspicion_45_64["rea_C19_suspicion_45_64"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_suspicion_45_64=df_rea_C19_suspicion_45_64["rea_C19_suspicion_45_64"].astype(float)
df2_rea_C19_suspicion_45_64=df2_rea_C19_suspicion_45_64.to_frame()
df_rea_C19_suspicion_45_64.drop(columns='rea_C19_suspicion_45_64',inplace=True)
df_rea_C19_suspicion_45_64=pd.concat([df_rea_C19_suspicion_45_64,df2_rea_C19_suspicion_45_64], axis=1)
#df_rea_C19_suspicion_45_64.drop(columns='Date',inplace=True)




df_rea_C19_suspicion_65_74["rea_C19_suspicion_65_74"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_suspicion_65_74=df_rea_C19_suspicion_65_74["rea_C19_suspicion_65_74"].astype(float)
df2_rea_C19_suspicion_65_74=df2_rea_C19_suspicion_65_74.to_frame()
df_rea_C19_suspicion_65_74.drop(columns='rea_C19_suspicion_65_74',inplace=True)
df_rea_C19_suspicion_65_74=pd.concat([df_rea_C19_suspicion_65_74,df2_rea_C19_suspicion_65_74], axis=1)
#df_rea_C19_suspicion_65_74.drop(columns='Date',inplace=True)


df_rea_C19_suspicion_75["rea_C19_suspicion_75"].replace(' ', '', regex=True, inplace=True)
df2_rea_C19_suspicion_75=df_rea_C19_suspicion_75["rea_C19_suspicion_75"].astype(float)
df2_rea_C19_suspicion_75=df2_rea_C19_suspicion_75.to_frame()
df_rea_C19_suspicion_75.drop(columns='rea_C19_suspicion_75',inplace=True)
df_rea_C19_suspicion_75=pd.concat([df_rea_C19_suspicion_75,df2_rea_C19_suspicion_75], axis=1)
#df_rea_C19_suspicion_75.drop(columns='Date',inplace=True)

# %%
df_mort_cum_C19.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19.csv', index = False, header=True)
df_mort_cum_C19_H.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19_H.csv', index = False, header=True)
df_mort_cum_C19_F.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19_F.csv', index = False, header=True)

df_hostpi_C19.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_hostpi_C19.csv', index = False, header=True)
df_hostpi_C19_H.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_hostpi_C19_H.csv', index = False, header=True)
df_hostpi_C19_F.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_hostpi_C19_F.csv', index = False, header=True)

df_rea_C19.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19.csv', index = False, header=True)
df_rea_C19_H.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_H.csv', index = False, header=True)
df_rea_C19_F.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_F.csv', index = False, header=True)


df_rea_C19_suspicion.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion.csv', index = False, header=True)
df_rea_C19_suspicion_15ans.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_15ans.csv', index = False, header=True)
df_rea_C19_suspicion_15_44.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_15_44.csv', index = False, header=True)
df_rea_C19_suspicion_45_64.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_45_64.csv', index = False, header=True)
df_rea_C19_suspicion_65_74.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_65_74.csv', index = False, header=True)
df_rea_C19_suspicion_75.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_75.csv', index = False, header=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7e151c108459> in <module>
# ----> 1 df_mort_cum_C19.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19.csv', index = False, header=True)
#       2 df_mort_cum_C19_H.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19_H.csv', index = False, header=True)
#       3 df_mort_cum_C19_F.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19_F.csv', index = False, header=True)
#       4
#       5 df_hostpi_C19.to_csv (r'/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_hostpi_C19.csv', index = False, header=True)
#
# NameError: name 'df_mort_cum_C19' is not defined

# %%
import pandas as pd

# %%
df_mort_cum_C19= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19.csv')
df_mort_cum_C19_H= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19_H.csv')
df_mort_cum_C19_F= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_mort_cum_C19_F.csv')

df_hostpi_C19= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_hostpi_C19.csv')
df_hostpi_C19_H= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_hostpi_C19_H.csv')
df_hostpi_C19_F= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_hostpi_C19_F.csv')

df_rea_C19= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19.csv')
df_rea_C19_H= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_H.csv')
df_rea_C19_F= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_F.csv')


df_rea_C19_suspicion= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion.csv')
df_rea_C19_suspicion_15ans= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_15ans.csv')
df_rea_C19_suspicion_15_44= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_15_44.csv')
df_rea_C19_suspicion_45_64= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_45_64.csv')
df_rea_C19_suspicion_65_74= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_65_74.csv')
df_rea_C19_suspicion_75= pd.read_csv('/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/df_rea_C19_suspicion_75.csv')

# %%
df_mort_cum_C19.head(20)
# Out:
#         Date  mort_cum_C19
# 0   2020-S10           7.0
# 1   2020-S11          94.0
# 2   2020-S12         523.0
# 3   2020-S13        1746.0
# 4   2020-S14        3766.0
# 5   2020-S15        5765.0
# 6   2020-S16        7459.0
# 7   2020-S17        8613.0
# 8   2020-S18        9391.0
# 9   2020-S19        9965.0
# 10  2020-S20       10338.0
# 11  2020-S21       10632.0
# 12  2020-S22       10834.0
# 13  2020-S23       10972.0
# 14  2020-S24       11065.0
# 15  2020-S25       11127.0
# 16  2020-S26       11169.0
# 17  2020-S27       11204.0
# 18  2020-S28       11228.0
# 19  2020-S29       11262.0

# %%
df_mort_cum_C19_2 =df_mort_cum_C19.copy()
df_mort_cum_C19_H_2 =df_mort_cum_C19_H.copy()
df_mort_cum_C19_F_2 =df_mort_cum_C19_F.copy()

# %%
import numpy as np

# %% [markdown]
# ### Fusion des tables mort covid 19

# %%
data_frames_0 = [df_mort_cum_C19_2, df_mort_cum_C19_H_2, df_mort_cum_C19_F_2 ]


df_mort_C19 = reduce(lambda left,right: pd.merge(left,right,on='Date'), data_frames_0)

# %%
df_mort_C19.head()

df_mort_C19_2=df_mort_C19.copy()

# %%
df_mort_C19_2['mort_cum_C19'] = np.nan
df_mort_C19_2['mort_cum_C19_H'] = np.nan
df_mort_C19_2['mort_cum_C19_F'] = np.nan

df_mort_C19_2.head()
# Out:
#        Date  mort_cum_C19  mort_cum_C19_H  mort_cum_C19_F
# 0  2020-S10           NaN             NaN             NaN
# 1  2020-S11           NaN             NaN             NaN
# 2  2020-S12           NaN             NaN             NaN
# 3  2020-S13           NaN             NaN             NaN
# 4  2020-S14           NaN             NaN             NaN

# %%
df_mort_C19_final=pd.concat([df_mort_C19,df_mort_C19_2,df_mort_C19_2,df_mort_C19_2,df_mort_C19_2,df_mort_C19_2,df_mort_C19_2], ignore_index=True)

# %%
df_mort_C19_final.sort_values("Date", ascending=True, inplace=True)

# %%
df_mort_C19_final.head(30)
# Out:
#          Date  mort_cum_C19  mort_cum_C19_H  mort_cum_C19_F
# 0    2020-S10           7.0             4.0             3.0
# 156  2020-S10           NaN             NaN             NaN
# 195  2020-S10           NaN             NaN             NaN
# 78   2020-S10           NaN             NaN             NaN
# 234  2020-S10           NaN             NaN             NaN
# 39   2020-S10           NaN             NaN             NaN
# 117  2020-S10           NaN             NaN             NaN
# 157  2020-S11           NaN             NaN             NaN
# 235  2020-S11           NaN             NaN             NaN
# 118  2020-S11           NaN             NaN             NaN
# 79   2020-S11           NaN             NaN             NaN
# 196  2020-S11           NaN             NaN             NaN
# 1    2020-S11          94.0            55.0            39.0
# 40   2020-S11           NaN             NaN             NaN
# 80   2020-S12           NaN             NaN             NaN
# ...

# %%
df_mort_C19_final['Date'] = pd.date_range(start='03/02/2020', periods=len(df_mort_C19_final), freq='D')

# %%
df_mort_C19_final.head()
# Out:
#           Date  mort_cum_C19  mort_cum_C19_H  mort_cum_C19_F
# 0   2020-03-02           7.0             4.0             3.0
# 156 2020-03-03           NaN             NaN             NaN
# 195 2020-03-04           NaN             NaN             NaN
# 78  2020-03-05           NaN             NaN             NaN
# 234 2020-03-06           NaN             NaN             NaN

# %% [markdown]
# ### Interpolation des tables mort covid 19

# %%
df_mort_C19_final2 = df_mort_C19_final.interpolate()
df_mort_C19_final2.head(13)
# Out:
#           Date  mort_cum_C19  mort_cum_C19_H  mort_cum_C19_F
# 0   2020-03-02          7.00            4.00             3.0
# 156 2020-03-03         14.25            8.25             6.0
# 195 2020-03-04         21.50           12.50             9.0
# 78  2020-03-05         28.75           16.75            12.0
# 234 2020-03-06         36.00           21.00            15.0
# 39  2020-03-07         43.25           25.25            18.0
# 117 2020-03-08         50.50           29.50            21.0
# 157 2020-03-09         57.75           33.75            24.0
# 235 2020-03-10         65.00           38.00            27.0
# 118 2020-03-11         72.25           42.25            30.0
# 79  2020-03-12         79.50           46.50            33.0
# 196 2020-03-13         86.75           50.75            36.0
# 1   2020-03-14         94.00           55.00            39.0

# %% [markdown]
# ### Fusion des tables hostpitalisation covid 19

# %%
from datetime import datetime 
from functools import reduce

# %%
data_frames = [df_hostpi_C19, df_hostpi_C19_H, df_hostpi_C19_F,df_rea_C19, df_rea_C19_H, df_rea_C19_F, df_rea_C19_suspicion, df_rea_C19_suspicion_15ans,df_rea_C19_suspicion_15_44,
              df_rea_C19_suspicion_45_64,df_rea_C19_suspicion_65_74, df_rea_C19_suspicion_75 ]


df_final = reduce(lambda left,right: pd.merge(left,right,on='Date'), data_frames)

# %%
df_final.head()
# Out:
#          Date  hostpi_C19  hostpi_C19_H  hostpi_C19_F  rea_C19  rea_C19_H  \
# 0  2020-03-18      2972.0        1685.0        1248.0    771.0      525.0
# 1  2020-03-19      4073.0        2256.0        1632.0   1002.0      689.0
# 2  2020-03-20      5226.0        2912.0        2134.0   1297.0      905.0
# 3  2020-03-21      5900.0        3298.0        2401.0   1453.0     1018.0
# 4  2020-03-22      6954.0        3906.0        2815.0   1674.0     1176.0
#
#    rea_C19_F  rea_C19_suspicion  rea_C19_suspicion_15ans  \
# 0      239.0             2355.0                     96.0
# 1      284.0             2367.0                     94.0
# 2      362.0             2882.0                     82.0
# 3      401.0             2696.0                     83.0
# 4      461.0             2818.0                     75.0
#
#    rea_C19_suspicion_15_44  rea_C19_suspicion_45_64  rea_C19_suspicion_65_74  \
# 0                   1019.0                    699.0                    233.0
# ...

# %% [markdown]
# ### Fusion des tables maladies

# %%
import numpy as np

# %%
df_maladie= pd.read_csv("/Users/antoineloubeyre/Desktop/Cours_ENSAE/Semestre1/Python/DataFrame/maladie.csv", parse_dates=False)
df_maladie2= df_maladie.copy()
df_maladie3= df_maladie.copy()

# %%
df_maladie2.drop(df_maladie2.index[0], inplace=True)
df_maladie2.head()
df_maladie2['Asthme'] = np.nan
df_maladie2['allergie'] = np.nan
df_maladie2['bronchite'] = np.nan
df_maladie2['grippe'] = np.nan
df_maladie2['Orl'] = np.nan
df_maladie2['Pneumo'] = np.nan
df_maladie2.head()
# Out:
#        Date  Asthme  allergie  bronchite  grippe  Orl  Pneumo
# 1  2010-S01     NaN       NaN        NaN     NaN  NaN     NaN
# 2  2010-S02     NaN       NaN        NaN     NaN  NaN     NaN
# 3  2010-S03     NaN       NaN        NaN     NaN  NaN     NaN
# 4  2010-S04     NaN       NaN        NaN     NaN  NaN     NaN
# 5  2010-S05     NaN       NaN        NaN     NaN  NaN     NaN

# %%
df_maladie_all=pd.concat([df_maladie,df_maladie2,df_maladie2,df_maladie2,df_maladie2,df_maladie2,df_maladie2], ignore_index=True)

# %%
df_maladie_all.drop(df_maladie_all.index[0], inplace=True)
df_maladie_all.head()
# Out:
#        Date  Asthme  allergie  bronchite   grippe    Orl  Pneumo
# 1  2010-S01  2646.0     637.0     2646.0  10367.0  424.0  6750.0
# 2  2010-S02  2606.0     491.0     2606.0   8408.0  512.0  6303.0
# 3  2010-S03  2547.0     689.0     2547.0   5986.0  335.0  5922.0
# 4  2010-S04  2717.0     644.0     2717.0   6542.0  481.0  6071.0
# 5  2010-S05  2570.0     670.0     2570.0   4317.0  400.0  6003.0

# %%
df_maladie_all.sort_values("Date", ascending=True, inplace=True)
df_maladie_all.head(10)
# Out:
#           Date  Asthme  allergie  bronchite   grippe    Orl  Pneumo
# 1     2010-S01  2646.0     637.0     2646.0  10367.0  424.0  6750.0
# 3433  2010-S01     NaN       NaN        NaN      NaN    NaN     NaN
# 573   2010-S01     NaN       NaN        NaN      NaN    NaN     NaN
# 1717  2010-S01     NaN       NaN        NaN      NaN    NaN     NaN
# 1145  2010-S01     NaN       NaN        NaN      NaN    NaN     NaN
# 2861  2010-S01     NaN       NaN        NaN      NaN    NaN     NaN
# 2289  2010-S01     NaN       NaN        NaN      NaN    NaN     NaN
# 3434  2010-S02     NaN       NaN        NaN      NaN    NaN     NaN
# 2     2010-S02  2606.0     491.0     2606.0   8408.0  512.0  6303.0
# 574   2010-S02     NaN       NaN        NaN      NaN    NaN     NaN

# %%
df_maladie_all.shape
# Out:
# (4004, 7)

# %%
df_maladie_all['Date'] = pd.date_range(start='01/11/2010', periods=len(df_maladie_all), freq='D')

# %%
df_maladie_all.head(10)
# Out:
#            Date  Asthme  allergie  bronchite   grippe    Orl  Pneumo
# 1    2010-01-11  2646.0     637.0     2646.0  10367.0  424.0  6750.0
# 3433 2010-01-12     NaN       NaN        NaN      NaN    NaN     NaN
# 573  2010-01-13     NaN       NaN        NaN      NaN    NaN     NaN
# 1717 2010-01-14     NaN       NaN        NaN      NaN    NaN     NaN
# 1145 2010-01-15     NaN       NaN        NaN      NaN    NaN     NaN
# 2861 2010-01-16     NaN       NaN        NaN      NaN    NaN     NaN
# 2289 2010-01-17     NaN       NaN        NaN      NaN    NaN     NaN
# 3434 2010-01-18     NaN       NaN        NaN      NaN    NaN     NaN
# 2    2010-01-19  2606.0     491.0     2606.0   8408.0  512.0  6303.0
# 574  2010-01-20     NaN       NaN        NaN      NaN    NaN     NaN

# %%
df_maladie_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4004 entries, 1 to 4004
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4004 non-null   datetime64[ns]
#  1   Asthme     572 non-null    float64
#  2   allergie   572 non-null    float64
#  3   bronchite  572 non-null    float64
#  4   grippe     572 non-null    float64
#  5   Orl        572 non-null    float64
#  6   Pneumo     572 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 250.2 KB

# %% [markdown]
# ### Interpolation des tables maladies

# %%
df_maladie_all2 = df_maladie_all.interpolate()
df_maladie_all2.head(10)
# Out:
#            Date    Asthme  allergie  bronchite     grippe      Orl    Pneumo
# 1    2010-01-11  2646.000    637.00   2646.000  10367.000  424.000  6750.000
# 3433 2010-01-12  2641.000    618.75   2641.000  10122.125  435.000  6694.125
# 573  2010-01-13  2636.000    600.50   2636.000   9877.250  446.000  6638.250
# 1717 2010-01-14  2631.000    582.25   2631.000   9632.375  457.000  6582.375
# 1145 2010-01-15  2626.000    564.00   2626.000   9387.500  468.000  6526.500
# 2861 2010-01-16  2621.000    545.75   2621.000   9142.625  479.000  6470.625
# 2289 2010-01-17  2616.000    527.50   2616.000   8897.750  490.000  6414.750
# 3434 2010-01-18  2611.000    509.25   2611.000   8652.875  501.000  6358.875
# 2    2010-01-19  2606.000    491.00   2606.000   8408.000  512.000  6303.000
# 574  2010-01-20  2598.625    515.75   2598.625   8105.250  489.875  6255.375

# %%
#df_maladie_all['Date'] = pd.to_datetime(df_maladie_all['Date'])
#df_maladie_all.info()

# %%
df_final.head()
# Out:
#          Date  hostpi_C19  hostpi_C19_H  hostpi_C19_F  rea_C19  rea_C19_H  \
# 0  2020-03-18      2972.0        1685.0        1248.0    771.0      525.0
# 1  2020-03-19      4073.0        2256.0        1632.0   1002.0      689.0
# 2  2020-03-20      5226.0        2912.0        2134.0   1297.0      905.0
# 3  2020-03-21      5900.0        3298.0        2401.0   1453.0     1018.0
# 4  2020-03-22      6954.0        3906.0        2815.0   1674.0     1176.0
#
#    rea_C19_F  rea_C19_suspicion  rea_C19_suspicion_15ans  \
# 0      239.0             2355.0                     96.0
# 1      284.0             2367.0                     94.0
# 2      362.0             2882.0                     82.0
# 3      401.0             2696.0                     83.0
# 4      461.0             2818.0                     75.0
#
#    rea_C19_suspicion_15_44  rea_C19_suspicion_45_64  rea_C19_suspicion_65_74  \
# 0                   1019.0                    699.0                    233.0
# ...

# %% [markdown]
# ### Sélection des tables à partir du 18 mars 2020

# %%
df_maladie_all3=df_maladie_all2.loc[(df_maladie_all2['Date'] >= "2020-03-18")]

# %%
df_mort_C19_final3=df_mort_C19_final2.loc[(df_mort_C19_final2['Date'] >= "2020-03-18")]

# %%
#df_maladie_all2.dropna(inplace=True)
#df_mort_C19_final3.dropna(inplace=True)

# %%
df_maladie_all3.head(10)
# Out:
#            Date  Asthme  allergie  bronchite   grippe    Orl  Pneumo
# 1104 2020-03-18  2249.0     845.6     2249.0  11812.4  398.2  6160.4
# 3964 2020-03-19  2241.5     848.9     2241.5  11794.6  402.8  6186.6
# 2248 2020-03-20  2234.0     852.2     2234.0  11776.8  407.4  6212.8
# 3392 2020-03-21  2226.5     855.5     2226.5  11759.0  412.0  6239.0
# 2820 2020-03-22  2219.0     858.8     2219.0  11741.2  416.6  6265.2
# 2821 2020-03-23  2211.5     862.1     2211.5  11723.4  421.2  6291.4
# 1105 2020-03-24  2204.0     865.4     2204.0  11705.6  425.8  6317.6
# 2249 2020-03-25  2196.5     868.7     2196.5  11687.8  430.4  6343.8
# 533  2020-03-26  2189.0     872.0     2189.0  11670.0  435.0  6370.0
# 3965 2020-03-27  2203.3     865.9     2203.3  11665.4  430.5  6377.0

# %%
df_mort_C19_final3.head(10)
# Out:
#           Date  mort_cum_C19  mort_cum_C19_H  mort_cum_C19_F
# 197 2020-03-18       308.500           175.0         133.500
# 41  2020-03-19       362.125           205.0         157.125
# 236 2020-03-20       415.750           235.0         180.750
# 119 2020-03-21       469.375           265.0         204.375
# 2   2020-03-22       523.000           295.0         228.000
# 120 2020-03-23       828.750           479.0         349.750
# 237 2020-03-24      1134.500           663.0         471.500
# 81  2020-03-25      1440.250           847.0         593.250
# 3   2020-03-26      1746.000          1031.0         715.000
# 42  2020-03-27      2251.000          1320.0         931.000

# %%
df_final['Date'] = pd.to_datetime(df_final['Date'])

# %% [markdown]
# ### Fusion des 3 tables

# %%
data_frames_3 = [df_final, df_maladie_all3,df_mort_C19_final3 ]
df_final_2 = reduce(lambda left,right: pd.merge(left,right,on='Date'), data_frames_3)

# %%
df_final_2.head(10)
# Out:
#         Date  hostpi_C19  hostpi_C19_H  hostpi_C19_F  rea_C19  rea_C19_H  \
# 0 2020-03-18      2972.0        1685.0        1248.0    771.0      525.0
# 1 2020-03-19      4073.0        2256.0        1632.0   1002.0      689.0
# 2 2020-03-20      5226.0        2912.0        2134.0   1297.0      905.0
# 3 2020-03-21      5900.0        3298.0        2401.0   1453.0     1018.0
# 4 2020-03-22      6954.0        3906.0        2815.0   1674.0     1176.0
# 5 2020-03-23      8673.0        4882.0        3532.0   2080.0     1465.0
# 6 2020-03-24     10163.0        5843.0        4149.0   2503.0     1773.0
# 7 2020-03-25     12072.0        7064.0        4856.0   2935.0     2127.0
# 8 2020-03-26     13879.0        8152.0        5570.0   3351.0     2437.0
# 9 2020-03-27     15701.0        9288.0        6248.0   3758.0     2735.0
#
#    rea_C19_F  rea_C19_suspicion  rea_C19_suspicion_15ans  \
# 0      239.0             2355.0                     96.0
# ...

# %% [markdown]
# # Machine learning sur séries temporelles

# %%
import matplotlib.pyplot as plt

# %%
df_final3= df_final_2.set_index("Date")

# %%
df_final3.head()
# Out:
#             hostpi_C19  hostpi_C19_H  hostpi_C19_F  rea_C19  rea_C19_H  \
# Date
# 2020-03-18      2972.0        1685.0        1248.0    771.0      525.0
# 2020-03-19      4073.0        2256.0        1632.0   1002.0      689.0
# 2020-03-20      5226.0        2912.0        2134.0   1297.0      905.0
# 2020-03-21      5900.0        3298.0        2401.0   1453.0     1018.0
# 2020-03-22      6954.0        3906.0        2815.0   1674.0     1176.0
#
#             rea_C19_F  rea_C19_suspicion  rea_C19_suspicion_15ans  \
# Date
# 2020-03-18      239.0             2355.0                     96.0
# 2020-03-19      284.0             2367.0                     94.0
# 2020-03-20      362.0             2882.0                     82.0
# 2020-03-21      401.0             2696.0                     83.0
# 2020-03-22      461.0             2818.0                     75.0
#
#             rea_C19_suspicion_15_44  rea_C19_suspicion_45_64  ...  \
# ...

# %% [markdown]
# ### Aperçu graphique du resultat de l'intepolation de la variable grippe

# %%
plt.scatter(x = df_final3.index, y = df_final3["grippe"])

# %%
#Aperçu de toutes les variables
plt.style.use("fivethirtyeight")
ax=df_final3.plot(figsize=(14,7), fontsize=14)
ax.set_xlabel("Date")
ax.set_ylabel("Nombre de personnes")
plt.title("Représentation des différentes variables Covid19 en fonciton du temps")
# Out:
# Text(0.5, 1.0, 'Représentation des différentes variables Covid19 en fonciton du temps')

# %%
df_final3.plot(subplots=True, figsize=(30,30))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf88c55d60>,
# ...
#       dtype=object)

# %% [markdown]
# ### Stationnarité d'une série temporelle
#
# Une série chronologie peut être interprété à condition qu'elle soit stationnaire.
# Cela signifie que la distribution des données ne change pas au cours du temps.
#
# Pour qu'une série soit stationnaire, elle doit remplir 3 critères (pour chaque date t) :
#
# $\mathbb{E}$$(y_t)$ = m  : Aucune tendance <br>
# $\mathrm{Var}$$(y_t)$ = $\sigma^2$  : Variance constante <br>
# $\mathrm{Cov}$$(y_t, y_{t-k})$ = $\rho_k$    Autocorrelation est constante <br>
#
#
# Comme pour la modélisation en Machine Learning "classique", nous diviserons les données mais en fonction du temps.
# Les données du passées serviront à prédire les données futures
#
#
# Dans un premier temps, nous modéliserons la série temporelle **"Nombre de personnes mort du Covid 19"**

# %%
ax=df_final3["mort_cum_C19"].plot(figsize=(14,7), fontsize=14)
ax.set_xlabel("Date")
ax.set_ylabel("Nombre de personnes")
plt.title("Représentation de la variable 'mort Covid 19' en fonciton du temps")
plt.legend()

# %% [markdown]
# **Remarque** :
# A première vue, la série n'est pas stationnaire.
# Pour en être sûr, nous allons appliquer des méthodes plus formelle comme des tests statistiques.
#
# Le test le plus utilisé est le test de **Dicky-Fuller augmenté** :
#
#  <ins>Soit le modèle</ins> :  $y_t$ = $\rho$$y_{t-1}$ + $u_t$
#
# $H_0$ : $\rho$= 1 (la série n'est pas stationnaire) vs $H_0$ : $\lvert$ $\rho$ $\rvert$ $\lt$ 1 (la série est stationnaire)

# %%
from statsmodels.tsa.stattools import adfuller

results=adfuller(df_final3["mort_cum_C19"])
print(results)
# Out:
# (1.1229462869208446, 0.9954077794468826, 14, 242, {'1%': -3.457664132155201, '5%': -2.8735585105960224, '10%': -2.5731749894132916}, 2691.9500963494784)

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-4e1243bd22c6> in <module>
# ----> 1 test
#
# NameError: name 'test' is not defined

# %% [markdown]
#  <ins>Analyse résultat test</ins> : La deuxième élément représente la p-value, donc **0.99 > 0.05**  donc on ne rejette pas l'hypothèse $H_0$,
# la série n'est pas stationnaire.
#
# <ins>Solution</ins> : Pour que notre série devienne stationnaire, nous allons devoir la transformer. (C'est l'équivalent de la partie "features engineering" dans le Machine Learning classique)
#
# Pour cela, nous allons appliquer la différence :  $\Delta$ = $y_t$ - $y_{t-1}$

# %%
df_stationary= df_final3["mort_cum_C19"].diff().dropna()

# %%
from statsmodels.tsa.stattools import adfuller

results2=adfuller(df_stationary)
print(results2)
# Out:
# (-2.3666731203042937, 0.15136440315343613, 13, 242, {'1%': -3.457664132155201, '5%': -2.8735585105960224, '10%': -2.5731749894132916}, 2681.0586932958536)

# %% [markdown]
#  <ins>Analyse résultat test 2 </ins> : La deuxième élément représente la p-value, donc **0.15 > 0.05**  donc on ne rejette pas l'hypothèse $H_0$,
# la série n'est pas stationnaire.
#
# <ins>Solution</ins> : Nous allons devoir appliquer une autre méthode de transormation afin que notre série devienne stationnaire
#
# Pour cela, nous allons appliquer le log du ratio de différence :  $y_t$ = $\log$ $ \left( \frac{y_t}{Y_{t-1}} \right)$

# %%
df_stationary_mort = np.log(df_final3["mort_cum_C19"]/df_final3["mort_cum_C19"].shift(1))
df_stationary_mort = df_stationary_mort.dropna()

print(df_stationary_mort)
test=pd.DataFrame(df_stationary_mort)
test.isnull().sum()

df_stationary_mort.index = pd.DatetimeIndex(df_stationary_mort.index.values,
                               freq=df_stationary_mort.index.inferred_freq)
# Out:
# Date
# 2020-03-19    0.160268
# 2020-03-20    0.138095
# 2020-03-21    0.121318
# 2020-03-22    0.108179
# 2020-03-23    0.460337
#                 ...
# 2020-11-25    0.017362
# 2020-11-26    0.017065
# 2020-11-27    0.000000
# 2020-11-28    0.000000
# 2020-11-29    0.000000
# Name: mort_cum_C19, Length: 256, dtype: float64

# %%
results3=adfuller(df_stationary_mort)
print(results3)
# Out:
# (-18.822777401622343, 2.022168335685471e-30, 4, 251, {'1%': -3.4566744514553016, '5%': -2.8731248767783426, '10%': -2.5729436702592023}, -1972.9247866844585)

# %% [markdown]
#  <ins>Analyse résultat test 2 </ins> : La deuxième élément représente la p-value, donc **$2.03$ x $10^{-30}$ < $0.05$**  donc on  rejette l'hypothèse $H_0$,
# la série est stationnaire.

# %% [markdown]
# ### Sléection des meilleurs paramètres P et q
#
# L'un des principaux moyens d'identifier les bons paramètres consiste à utiliser la fonction d'autocorrélation ACF et/ou la fonction d'autocorrélation partielle PACF.
#
# ACF(p) : corr($y_t$, $y_{t-p}$)
#
# PACF(p) : représente la corrélation entre la série et la version décalée d'elle-même après avoir soustrait l'effet de la corrélation à des décalages plus petits
#
# En comparant l'ACF et le PACF, nous pouvons déduire l'ordre du modèle.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, (ax1, ax2) = plt.subplots(2,1, figsize=(8,8))

plot_acf(df_stationary_mort, lags=10, zero=False, ax=ax1)

plot_pacf(df_stationary_mort, lags=10, zero=False, ax=ax2)

# %% [markdown]
# Si les valeurs sont petites et se trouvent à l'intérieur de la zone ombrée en bleu, alors cela signifie qu'elles ne sont pas statistiquement significatives
#
# <ins>Analyse résultat test 3 </ins> : L'ACF nous indique un modèle AR(4), or la PACF s'arrête au retard 1 donc nous avons un modèle AR(1)

# %% [markdown]
# ### Modélisation 1 : Modèle AR, MA et ARMA

# %% [markdown]
#  <ins>Modèle AR(p)</ins> :  $y_t$ = $\alpha_1$$y_{t-1}$ + $\alpha_2$$y_{t-2}$ + ... + $\alpha_p$$y_{t-p}$+  $u_t$
#
#  <ins>Modèle MA(q)</ins> :  $y_t$ = $\beta_1$$u_{t-1}$ + $\beta_2$$u_{t-2}$ + ... + $\beta_q$$u_{t-q}$+  $u_t$
#
#   <ins>Modèle ARMA(p,q)</ins> :  $y_t$ = $\alpha_1$$y_{t-1}$ + $\alpha_2$$y_{t-2}$ + ... + $\alpha_p$$y_{t-p}$ + $\beta_1$$u_{t-1}$ + $\beta_2$$u_{t-2}$ + ... + $\beta_q$$u_{t-q}$+  $u_t$
#
#
#  ( $u_t$ représente le bruit blanc, cela signifie que chaque choc de la série à la date est aléatoire et n'est donc pas lié aux autres chocs de la série)

# %% [markdown]
# ### Modèle 1 :
#
# $ \left( \frac{mortCovid_t}{mortCovid_{t-1}} \right)$ =  $\alpha_0$ +$\alpha_1$ $\log$ $ \left( \frac{mortCovid_{t-1}}{mortCovid_{t-2}} \right)$ + $u_t$

# %%
from statsmodels.tsa.arima_model import ARMA

model= ARMA(df_stationary_mort, order=(1,0))

results= model.fit()

# %%
print(results.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:           mort_cum_C19   No. Observations:                  256
# Model:                     ARMA(1, 0)   Log Likelihood                 576.991
# Method:                       css-mle   S.D. of innovations              0.025
# Date:                Sat, 12 Dec 2020   AIC                          -1147.983
# Time:                        18:18:00   BIC                          -1137.347
# Sample:                    03-19-2020   HQIC                         -1143.705
#                          - 11-29-2020
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0197      0.011      1.722      0.085      -0.003       0.042
# ar.L1.mort_cum_C19     0.8645      0.033     26.433      0.000       0.800       0.929
#                                     Roots
# ...

# %% [markdown]
# <ins>Interprétation modèle 1 : ARMA(1,0)</ins> :
#
# $\alpha_1$ = 0.86 : représente le coefficient de la variable transformée. Le coefficient est significatif au seuil de 1%

# %% [markdown]
# ### Prévision du modèle 1 :
#
# Méthode One-step-ahead : prédiction d'une seule valeur à l'avance

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model=SARIMAX(df_stationary_mort, order=(1,0,0), trend='c')

results=model.fit()
forecast= results.get_prediction(start=-30)

mean_forecast = forecast.predicted_mean

confidence_intervals= forecast.conf_int()

plt.plot(df_stationary_mort.index, df_stationary_mort, label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')

# %% [markdown]
# ### Prédiction dynamique

# %%
results=model.fit()
forecast= results.get_prediction(start=-30, dynamic=True)

mean_forecast = forecast.predicted_mean

confidence_intervals= forecast.conf_int()

plt.plot(df_stationary_mort.index, df_stationary_mort, label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')

# %% [markdown]
# ### Prédiction out-Sample

# %%
forecast= results.get_forecast(steps=30, dynamic=True) #Prédiction de 30 jours

mean_forecast = forecast.predicted_mean

confidence_intervals= forecast.conf_int()

plt.plot(df_stationary_mort.index, df_stationary_mort, label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')

# %% [markdown]
# <ins>Interprétation de la prédiction out-sample : </ins> :
#
# Nous pouvons constater une augmentation du nombre de décès liés au Covid après le 29 novembre 2020

# %% [markdown]
# ### Modélisation 2 : Modèle ARMAX

# %% [markdown]
# Il existe une extension des modèles ARMA qui consiste à ajouter une variable exogène au modèle.
# C'est une combinaison entre un modèle ARMA et une régréssion linéaire.
# Ici nous allons essayé de voir si les maladies scrappées auparavant, à savoir :
#
# Grippe <br>
# Asthme <br>
# Allergie <br>
# Orl <br>
# Pneumopathie<br>
# Bronchite <br>
#
#
#
# <ins>Modèle ARMAX(1,1)</ins> :  $y_t$ = $\zeta_1$$x_t$ + $\alpha_1$$y_{t-1}$ + $\beta_1$$u_{t-1}$ + $u_t$

# %% [markdown]
# #### Staionnarisation de la variable grippe

# %%
#df_final2.drop(df_maladie_all.index[0], inplace=True)

results_g=adfuller(df_final3["grippe"])
print(results_g)
# Out:
# (-2.3877119296285048, 0.14523470402552424, 4, 252, {'1%': -3.4565688966099373, '5%': -2.8730786194395455, '10%': -2.5729189953388762}, 3559.1940494198197)

# %%
df_stationary_g= df_final3["grippe"].diff().dropna()

# %%
results_g2=adfuller(df_stationary_g)
print(results_g2)
# Out:
# (-6.39997185904504, 2.006769459930309e-08, 2, 253, {'1%': -3.4564641849494113, '5%': -2.873032730098417, '10%': -2.572894516864816}, 3549.790696138166)

# %%
df_stationary_g.index = pd.DatetimeIndex(df_stationary_g.index.values,
                               freq=df_stationary_mort.index.inferred_freq)

# %% [markdown]
# #### Staionnarisation de la variable asthme

# %%
results_a = adfuller(df_final3["Asthme"])
print(results_a)
# Out:
# (-2.3062859396580673, 0.1699486451028428, 3, 253, {'1%': -3.4564641849494113, '5%': -2.873032730098417, '10%': -2.572894516864816}, 2261.1711051243)

# %%
df_stationary_a= df_final3["Asthme"].diff().dropna()

# %%
results_a2=adfuller(df_stationary_a)
print(results_a2)
# Out:
# (-7.1619237699492775, 2.952856151587059e-10, 2, 253, {'1%': -3.4564641849494113, '5%': -2.873032730098417, '10%': -2.572894516864816}, 2254.6442787312544)

# %%
df_stationary_a.index = pd.DatetimeIndex(df_stationary_a.index.values,
                               freq=df_stationary_mort.index.inferred_freq)

# %% [markdown]
# #### Staionnarisation de la variable allergie

# %%
results_aa = adfuller(df_final3["allergie"])
print(results_aa)
# Out:
# (-4.348681813664034, 0.0003654554296791634, 4, 252, {'1%': -3.4565688966099373, '5%': -2.8730786194395455, '10%': -2.5729189953388762}, 1912.143237875463)

# %% [markdown]
# La série est déjà stationnaire

# %%
df_final3["allergie"].index = pd.DatetimeIndex(df_final3["allergie"].index.values,
                               freq=df_stationary_mort.index.inferred_freq)

# %%
df_final3["allergie"].drop(df_final3["allergie"].index[0], inplace=True)

# %% [markdown]
# #### Staionnarisation de la variable Orl

# %%
results_o = adfuller(df_final3["Orl"])
print(results_o)
# Out:
# (-2.0012008413700646, 0.2860468204245362, 3, 253, {'1%': -3.4564641849494113, '5%': -2.873032730098417, '10%': -2.572894516864816}, 1672.1825541895594)

# %%
df_stationary_o= df_final3["Orl"].diff().dropna()

# %%
results_o=adfuller(df_stationary_o)
print(results_o)
# Out:
# (-6.102185767633071, 9.775331626372934e-08, 2, 253, {'1%': -3.4564641849494113, '5%': -2.873032730098417, '10%': -2.572894516864816}, 1670.4147445177618)

# %%
df_stationary_o.index = pd.DatetimeIndex(df_stationary_o.index.values,
                               freq=df_stationary_mort.index.inferred_freq)

# %% [markdown]
# #### Staionnarisation de la variable Pneumopathie

# %%
results_p = adfuller(df_final3["Pneumo"])
print(results_p)
# Out:
# (-3.7530282562298125, 0.0034261640067488786, 2, 254, {'1%': -3.456360306409983, '5%': -2.8729872043802356, '10%': -2.572870232500465}, 2051.112924889894)

# %% [markdown]
# La série est déjà stationnaire

# %%
df_final3["Pneumo"].index = pd.DatetimeIndex(df_final3["Pneumo"].index.values,
                               freq=df_stationary_mort.index.inferred_freq)

# %%
df_final3["Pneumo"].drop(df_final3["Pneumo"].index[0], inplace=True)

# %% [markdown]
# #### Staionnarisation de la variable Bronchite

# %%
results_b = adfuller(df_final3["bronchite"])
print(results_b)
# Out:
# (-2.3062859396580673, 0.1699486451028428, 3, 253, {'1%': -3.4564641849494113, '5%': -2.873032730098417, '10%': -2.572894516864816}, 2261.1711051243)

# %%
df_stationary_b= df_final3["bronchite"].diff().dropna()

# %%
results_b=adfuller(df_stationary_b)
print(results_b)
# Out:
# (-7.1619237699492775, 2.952856151587059e-10, 2, 253, {'1%': -3.4564641849494113, '5%': -2.873032730098417, '10%': -2.572894516864816}, 2254.6442787312544)

# %% [markdown]
# ### Création du model ARMAX avec la variable grippe
#
# $mortCovid_t$ = $\alpha$$grippe_{t}$  + $\zeta$$mortCovid_{t-1}$ +  $u_t$

# %%
model = ARMA(df_stationary_mort, order=(1,0), exog= df_stationary_g)

results_arma1= model.fit()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %%
print(results_arma1.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:           mort_cum_C19   No. Observations:                  256
# Model:                     ARMA(1, 0)   Log Likelihood                 575.801
# Method:                       css-mle   S.D. of innovations              0.025
# Date:                Sun, 13 Dec 2020   AIC                          -1143.602
# Time:                        11:03:45   BIC                          -1129.421
# Sample:                    03-19-2020   HQIC                         -1137.898
#                          - 11-29-2020
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0167      0.008      2.053      0.040       0.001       0.033
# grippe             -2.334e-06   2.86e-06     -0.817      0.414   -7.93e-06    3.26e-06
# ...

# %% [markdown]
# ### Création du model ARMAX avec la variable asthme
#
# $mortCovid_t$ = $\alpha$$asthme_{t}$  + $\zeta$$mortCovid_{t-1}$  +  $u_t$

# %%
model = ARMA(df_stationary_mort, order=(1,0), exog= df_stationary_a)
results_arma2= model.fit()

# %%
print(results_arma2.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:           mort_cum_C19   No. Observations:                  256
# Model:                     ARMA(1, 0)   Log Likelihood                 577.578
# Method:                       css-mle   S.D. of innovations              0.025
# Date:                Sun, 13 Dec 2020   AIC                          -1147.156
# Time:                        11:04:45   BIC                          -1132.975
# Sample:                    03-19-2020   HQIC                         -1141.452
#                          - 11-29-2020
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0198      0.012      1.703      0.089      -0.003       0.043
# Asthme             -4.793e-05   4.42e-05     -1.085      0.278      -0.000    3.86e-05
# ...

# %% [markdown]
# ### Création du model ARMAX avec la variable allergie
#
# $mortCovid_t$ = $\alpha$$allergie_{t}$  + $\zeta$$mortCovid_{t-1}$ + $\beta$$u_{t-1}$ +  $u_t$

# %%
model = ARMA(df_stationary_mort, order=(1,0), exog= df_final3["allergie"])
results_arma3= model.fit()

# %%
print(results_arma3.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:           mort_cum_C19   No. Observations:                  256
# Model:                     ARMA(1, 0)   Log Likelihood                 577.931
# Method:                       css-mle   S.D. of innovations              0.025
# Date:                Sun, 13 Dec 2020   AIC                          -1147.861
# Time:                        11:09:38   BIC                          -1133.681
# Sample:                    03-19-2020   HQIC                         -1142.158
#                          - 11-29-2020
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.1194      0.066      1.820      0.069      -0.009       0.248
# allergie              -0.0001   6.65e-05     -1.545      0.122      -0.000    2.76e-05
# ...

# %% [markdown]
# ### Création du model ARMAX avec la variable ORL
#
# $mortCovid_t$ = $\alpha$$Orl_{t}$  + $\zeta$$mortCovid_{t-1}$ + $\beta$$u_{t-1}$ +  $u_t$

# %%
model = ARMA(df_stationary_mort, order=(1,0), exog= df_stationary_o)
results_arma4= model.fit()

# %%
print(results_arma4.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:           mort_cum_C19   No. Observations:                  256
# Model:                     ARMA(1, 0)   Log Likelihood                 578.654
# Method:                       css-mle   S.D. of innovations              0.025
# Date:                Sun, 13 Dec 2020   AIC                          -1149.308
# Time:                        11:14:53   BIC                          -1135.127
# Sample:                    03-19-2020   HQIC                         -1143.604
#                          - 11-29-2020
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0200      0.012      1.632      0.103      -0.004       0.044
# Orl                   -0.0002   8.48e-05     -1.838      0.066      -0.000    1.03e-05
# ...

# %% [markdown]
# ### Création du model ARMAX avec la variable Pneumopathie
#
# $mortCovid_t$ = $\alpha$$Pneumopathie_{t}$  + $\zeta$$mortCovid_{t-1}$ +  $u_t$

# %%
model = ARMA(df_stationary_mort, order=(1,0), exog= df_final3["Pneumo"])
results_arma5= model.fit()

# %%
print(results_arma5.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:           mort_cum_C19   No. Observations:                  256
# Model:                     ARMA(1, 0)   Log Likelihood                 590.449
# Method:                       css-mle   S.D. of innovations              0.024
# Date:                Sun, 13 Dec 2020   AIC                          -1172.898
# Time:                        11:15:42   BIC                          -1158.717
# Sample:                    03-19-2020   HQIC                         -1167.194
#                          - 11-29-2020
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  1.1509      0.146      7.887      0.000       0.865       1.437
# Pneumo                -0.0002   2.06e-05     -7.765      0.000      -0.000      -0.000
# ...

# %% [markdown]
# ### Création du model ARMAX avec la variable Bronchite
#
# $mortCovid_t$ = $\alpha$$Bronchite_{t}$  + $\zeta$$mortCovid_{t-1}$ +  $u_t$

# %%
model = ARMA(df_stationary_mort, order=(1,0), exog= df_stationary_b)
results_arma6= model.fit()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
print(results_arma6.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:           mort_cum_C19   No. Observations:                  256
# Model:                     ARMA(1, 0)   Log Likelihood                 577.578
# Method:                       css-mle   S.D. of innovations              0.025
# Date:                Sun, 13 Dec 2020   AIC                          -1147.156
# Time:                        11:19:36   BIC                          -1132.975
# Sample:                    03-19-2020   HQIC                         -1141.452
#                          - 11-29-2020
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0198      0.012      1.703      0.089      -0.003       0.043
# bronchite          -4.793e-05   4.42e-05     -1.085      0.278      -0.000    3.86e-05
# ...

# %% [markdown]
# ### Analyse temporelle de la variable nombre de personnes hostpitalisés (sans transformation de la série)
#
# Au lieu de prendre la différence ou tout autre transformation de la série temporelle, nous allons prendre la somme cumulée (ou intégrale).
# Cette transformation nous permettra de réaliser des prédictions des valeurs "brute" de la série. Les modèles ARIMA représentes une extensions des modèles ARMA avec en plus un paramètre de différentiation auto-intégré.
#
# ARIMA : Autoregressive integrated Moving Average
#
# Cette méthode ne peut pas s'appliquer à la variable "mort covid 19" car nous avons appliquer une transformation logarithmique et non une transformation différentielle

# %% [markdown]
# ### Aperçu du nombre de lag nécessaire à la staionnarisation de la variable hostpitalisation C19

# %%
results=adfuller(df_final3["hostpi_C19"])
print(results)
# Out:
# (-1.8946209948256418, 0.33459578039779925, 16, 240, {'1%': -3.4578942529658563, '5%': -2.8736593200231484, '10%': -2.573228767361111}, 3120.16703451009)

# %%
df_stationary_h= df_final3["hostpi_C19"].diff().dropna()

# %%
results2=adfuller(df_stationary_h)
print(results2)
# Out:
# (-3.8016159344709792, 0.0028908250740959747, 15, 240, {'1%': -3.4578942529658563, '5%': -2.8736593200231484, '10%': -2.573228767361111}, 3103.061704768709)

# %% [markdown]
# La variable "hospit C19" (nombre de personnes hostpitalisés du Covid 19) nécessite de différencié 1 seule fois

# %% [markdown]
# ### recherche du meilleur paramètre

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, (ax1, ax2) = plt.subplots(2,1, figsize=(8,8))

plot_acf(df_stationary_h, lags=10, zero=False, ax=ax1)

plot_pacf(df_stationary_h, lags=10, zero=False, ax=ax2)

# %%
df_final3["hostpi_C19"].index = pd.DatetimeIndex(df_final3["hostpi_C19"].index.values,
                               freq=df_stationary_mort.index.inferred_freq)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(df_final3["hostpi_C19"], order=(1,1,0))

model_results=model.fit()

mean_forecast= model_results.get_forecast(steps=30).predicted_mean


plt.plot(df_final3["hostpi_C19"].index, df_final3["hostpi_C19"], label='observed')
plt.plot(mean_forecast.index, mean_forecast.values, color='red', label='forecast')
